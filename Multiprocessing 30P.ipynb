# %%
import numpy as np
import scipy
import matplotlib.pylab as plt
from matplotlib.pyplot import figure
from scipy.integrate import odeint
from scipy.optimize import minimize
import pickle
from timeit import default_timer as timer
import sys, getopt
import time
import csv
import multiprocessing as mp
from multiprocessing import Pool
import os
import pandas as pd
from scipy.optimize import Bounds

# %%
from two_pop_params_current import *
from init_cond_current import *

# %%
from coronavirusEqs import *
from ineq_measures_alone import *
from plotting_fn import *
from deaths_30 import *

# %%
#ref_dirs_10k_30p = np.zeros((10000,8))
#for i in range(10000):
#    it = 0
#    test=np.random.rand(8)
#    while (test[0:4]@y0_use[1:5]+test[4:]@y0_use[6:10])>0.3*N:
#        test=np.random.rand(8)
#    ref_dirs_10k_30p[i,:]=test
#np.savetxt('ref_dirs_10k_30p.txt', ref_dirs_10k_30p)
#ref_dirs_10k_30p=np.loadtxt('ref_dirs_10k_30p.txt')

ref_dirs_10k_30p=np.loadtxt('ref_dirs_10k_30p.txt')

# %%
def check_constraint(p,pops):
    return (p[0:4]@pops[1:5]+p[4:]@pops[6:10])<0.3*N

# %% [markdown]
# # 30 % Cost Constraint (deaths)

# %%
sp_1 = np.array([0,0,0.4,1,1,1,1,1])
sp_2 = np.array([0,.3,1,1,0,1,1,1])
sp_3 = np.array([0, 0.5, 1, 1, 0, 0, 1, 1])
sp_4 = np.array([0., 0.7, 1  , 1 , 0.  , 0.  , 0., 1.])

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(sp_death_30,[d for d in ref_dirs_10k_30p])
out = np.array(output)
idx = out.argsort()[:20]
starting_points_d30_01 = ref_dirs_10k_30p[idx]
starting_points_d30_01 = np.append(starting_points_d30_01,sp_1).reshape(21,8)
starting_points_d30_01 = np.append(starting_points_d30_01,sp_2).reshape(22,8)
starting_points_d30_01 = np.append(starting_points_d30_01,sp_3).reshape(23,8)
starting_points_d30_01 = np.append(starting_points_d30_01,sp_4).reshape(24,8)
#np.savetxt('starting_points_30p_combo0_death.txt', starting_points_d30_01)

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(sp_ineq_bars_30,[d for d in ref_dirs_10k_30p])
out = np.array(output)
idx = out.argsort()[:20]
starting_points_d30_30 = ref_dirs_10k_30p[idx]
starting_points_d30_30 = np.append(starting_points_d30_30,sp_1).reshape(21,8)
starting_points_d30_30 = np.append(starting_points_d30_30,sp_2).reshape(22,8)
starting_points_d30_30 = np.append(starting_points_d30_30,sp_3).reshape(23,8)
starting_points_d30_30 = np.append(starting_points_d30_30,sp_4).reshape(24,8)
np.savetxt('starting_points_30p_combo0_ineq_bars.txt', starting_points_d30_30)

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(sp_ineq_mort_30,[d for d in ref_dirs_10k_30p])
out = np.array(output)
idx = out.argsort()[:20]
starting_points_d30_30 = ref_dirs_10k_30p[idx]
starting_points_d30_30 = np.append(starting_points_d30_30,sp_1).reshape(21,8)
starting_points_d30_30 = np.append(starting_points_d30_30,sp_2).reshape(22,8)
starting_points_d30_30 = np.append(starting_points_d30_30,sp_3).reshape(23,8)
starting_points_d30_30 = np.append(starting_points_d30_30,sp_4).reshape(24,8)
np.savetxt('starting_points_30p_combo0_ineq_mort.txt', starting_points_d30_30)

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(sp_ineq_mort_IDIS_30,[d for d in ref_dirs_10k_30p])
out = np.array(output)
idx = out.argsort()[:20]
starting_points_ineq_mi_30 = ref_dirs_10k_30p[idx]
starting_points_ineq_mi_30 = np.append(starting_points_ineq_mi_30,sp_1).reshape(21,8)
starting_points_ineq_mi_30 = np.append(starting_points_ineq_mi_30,sp_2).reshape(22,8)
starting_points_ineq_mi_30 = np.append(starting_points_ineq_mi_30,sp_3).reshape(23,8)
starting_points_ineq_mi_30 = np.append(starting_points_ineq_mi_30,sp_4).reshape(24,8)
np.savetxt('starting_points_30p_combo0_ineq_mi.txt', starting_points_ineq_mi_30)

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(sp_both_bars_30,[d for d in ref_dirs_10k_30p])
out = np.array(output)
idx = out.argsort()[:20]
starting_points_bb_30 = ref_dirs_10k_30p[idx]
starting_points_bb_30 = np.append(starting_points_bb_30,sp_2).reshape(21,8)
starting_points_bb_30 = np.append(starting_points_bb_30,sp_3).reshape(22,8)
starting_points_bb_30 = np.append(starting_points_bb_30,sp_4).reshape(23,8)
starting_points_bb_30 = np.append(starting_points_bb_30,sp_1).reshape(24,8)
np.savetxt('starting_points_30p_combo0_bb.txt', starting_points_bb_30)

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(sp_both_mort_30,[d for d in ref_dirs_10k_30p])
out = np.array(output)
idx = out.argsort()[:20]
starting_points_bm_30 = ref_dirs_10k_30p[idx]
starting_points_bm_30 = np.append(starting_points_bm_30,sp_2).reshape(21,8)
starting_points_bm_30 = np.append(starting_points_bm_30,sp_3).reshape(22,8)
starting_points_bm_30 = np.append(starting_points_bm_30,sp_4).reshape(23,8)
starting_points_bm_30 = np.append(starting_points_bm_30,sp_1).reshape(24,8)
np.savetxt('starting_points_30p_combo0_bm.txt', starting_points_bm_30)

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(sp_both_mort_IDIS_30,[d for d in ref_dirs_10k_30p])
out = np.array(output)
idx = out.argsort()[:20]
starting_points_bi_30 = ref_dirs_10k_30p[idx]
starting_points_bi_30 = np.append(starting_points_bi_30,sp_2).reshape(21,8)
starting_points_bi_30 = np.append(starting_points_bi_30,sp_3).reshape(22,8)
starting_points_bi_30 = np.append(starting_points_bi_30,sp_4).reshape(23,8)
starting_points_bi_30 = np.append(starting_points_bi_30,sp_1).reshape(24,8)
np.savetxt('starting_points_30p_combo0_bi.txt', starting_points_bi_30)

# %%
starting_points_deaths_30  = np.loadtxt('starting_points_30p_combo0_death.txt')
starting_points_ineq_bars_30 =np.loadtxt('starting_points_30p_combo0_ineq_bars.txt')
starting_points_ineq_mort_30  = np.loadtxt('starting_points_30p_combo0_ineq_mort.txt')
starting_points_ineq_ai_30 = np.loadtxt('starting_points_30p_combo0_ineq_mi.txt')
starting_points_bb_30 = np.loadtxt('starting_points_30p_combo0_bb.txt')
starting_points_bm_30 = np.loadtxt('starting_points_30p_combo0_bm.txt')
starting_points_bi_30=np.loadtxt('starting_points_30p_combo0_bi.txt')

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(worker_death_30,[d for d in starting_points_deaths_30])
out01 = np.array(output)

print(np.round(out01[np.argmin(out01[:,1]),:][0],2))
#np.savetxt('worker_death_30_sol.txt', out01[np.argmin(out01[:,1]),:][0])
# Out:
# [0.   0.36 1.   1.   0.   1.   1.   1.  ]

# %%
sol_d30 = np.loadtxt('worker_death_30_sol.txt')

y0_new=y0_use.copy()
y0_new = y0_new.reshape(21,10)
y0_new[18] = np.zeros(10)
y0_new=y0_new.reshape(210)
p = sol_d30
y0_new=vaccinate_sus_y0(p,y0_new)
t = np.linspace(0,4*4*7,300)
sol=scipy.integrate.solve_ivp(lambda t,y:coronavirusEqs_with_vaccination_only(t,y, params),[0,4*4*7], y0_new, t_eval=t)
sol_plot=np.reshape(sol.y,(21,10,300))
deaths = sol_plot[18,:,-1]-deaths_from_curr_inf 
print("Total deaths:",np.round(sum(deaths)))
print("Deaths:",deaths)
print("Inequity in deaths (bars):", calc_death_bars(deaths,total_pops))
print("Inequity in deaths (diff):",calc_mort_diff(deaths,total_pops))
print("Inequity in deaths (ID):",calc_mort_idis(deaths,total_pops,total_pops_age))
print("YLLs:",sum(calc_ylls(deaths,two_pop_daly,total_pops),1))
print("Inequity in YLLs (diff):",calc_yll_diff(deaths,two_pop_daly,total_pops))
print("Inequity in YLLs (ID):",calc_index_idis(deaths,two_pop_daly,total_pops))
#np.savetxt('min_deaths_30.txt', deaths)
sum(abs(plotting_fun2(deaths,total_pops)-1))
# Out:
# Total deaths: 11.0
# Deaths: [ 2.09301569e-01  1.76792176e+00  4.50819707e+00  4.57454128e-08
#   1.48693765e-07  3.71384249e-01  3.80804320e+00 -7.44690976e-10
#  -3.51033247e-09  7.40240029e-08]
# Inequity in deaths (bars): 15.3304760919398
# Inequity in deaths (diff): 1.9309234706957636e-05
# Inequity in deaths (ID): 516.2299963477813
# YLLs: 85.55594882216991
# Inequity in YLLs (diff): 66.95117835921143
# Inequity in YLLs (ID): 527.6764828949097
# 16.281232269690733

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(worker_ineq_bars_30,[d for d in starting_points_ineq_bars_30])
out_ineq_bars_30 = np.array(output)

print(np.round(out_ineq_bars_30[np.argmin(out_ineq_bars_30[:,1]),:][0],2))
np.savetxt('worker_ineq_bars_30_sol.txt', out_ineq_bars_30[np.argmin(out_ineq_bars_30[:,1]),:][0])
# Out:
# [0.   0.04 0.7  0.22 0.82 0.81 0.92 0.63]

# %%
sol_ineq_bars_30= np.loadtxt('worker_ineq_bars_30_sol.txt')
print(check_constraint(sol_ineq_bars_30,y0_use[0:10]))
y0_new=y0_use.copy()
y0_new = y0_new.reshape(21,10)
y0_new[18] = np.zeros(10)
y0_new=y0_new.reshape(210)
p = sol_ineq_bars_30
y0_new=vaccinate_sus_y0(p,y0_new)
t = np.linspace(0,4*4*7,300)
sol=scipy.integrate.solve_ivp(lambda t,y:coronavirusEqs_with_vaccination_only(t,y, params),[0,4*4*7], y0_new, t_eval=t)
sol_plot=np.reshape(sol.y,(21,10,300))
deaths = sol_plot[18,:,-1]-deaths_from_curr_inf 
print("Total deaths:",np.round(sum(deaths)))
print("Deaths:",deaths)
print("Inequity in deaths (bars):", calc_death_bars(np.round(deaths, 2),total_pops))
print("Inequity in deaths (diff):",calc_mort_diff(deaths,total_pops))
print("Inequity in deaths (ID):",calc_mort_idis(deaths,total_pops,total_pops_age))
print("YLLs:",sum(calc_ylls(deaths,two_pop_daly,total_pops),1))
print("Inequity in YLLs (diff):",calc_yll_diff(deaths,two_pop_daly,total_pops))
print("Inequity in YLLs (ID):",calc_index_idis(deaths,two_pop_daly,total_pops))
np.savetxt('min_rel_ineq_deaths_30.txt', deaths)   
    
sum(abs(plotting_fun2(deaths,total_pops)-1))
# Out:
# True
# Total deaths: 153.0
# Deaths: [  0.22501586   1.96581747   8.21523265  11.91631983 116.66269201
#    0.38893599   0.69601539   1.734142     1.47402307  10.04948196]
# Inequity in deaths (bars): 2.6222844670418954
# Inequity in deaths (diff): 1.60373044271351e-06
# Inequity in deaths (ID): 73.61931968060927
# YLLs: 395.9352608374738
# Inequity in YLLs (diff): 13.886261139443832
# Inequity in YLLs (ID): 79.03781184302096
# 2.7020812677124786

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(worker_ineq_mort_30,[d for d in starting_points_ineq_mort_30])
out_ineq_mort_30 = np.array(output)

print(np.round(out_ineq_mort_30[np.argmin(out_ineq_mort_30[:,1]),:][0],2))
np.savetxt('worker_ineq_mort_30_sol.txt', out_ineq_mort_30[np.argmin(out_ineq_mort_30[:,1]),:][0])
# Out:
# [0.11 0.18 0.83 0.02 0.85 0.85 0.96 0.54]

# %%
sol_ineq_mort_30=np.loadtxt('worker_ineq_mort_30_sol.txt')

y0_new=y0_use.copy()
y0_new = y0_new.reshape(21,10)
y0_new[18] = np.zeros(10)
y0_new=y0_new.reshape(210)
p = sol_ineq_mort_30
y0_new=vaccinate_sus_y0(p,y0_new)
t = np.linspace(0,4*4*7,300)
sol=scipy.integrate.solve_ivp(lambda t,y:coronavirusEqs_with_vaccination_only(t,y, params),[0,4*4*7], y0_new, t_eval=t)
sol_plot=np.reshape(sol.y,(21,10,300))
deaths = sol_plot[18,:,-1]-deaths_from_curr_inf
print("Total deaths:",np.round(sum(deaths)))
print("Deaths:",deaths)
print("Inequity in deaths (bars):", calc_death_bars(deaths,total_pops))
print("Inequity in deaths (diff):",calc_mort_diff(deaths,total_pops))
print("Inequity in deaths (ID):",calc_mort_idis(deaths,total_pops,total_pops_age))
print("YLLs:",sum(calc_ylls(deaths,two_pop_daly,total_pops),1))
print("Inequity in YLLs (diff):",calc_yll_diff(deaths,two_pop_daly,total_pops))
print("Inequity in YLLs (ID):",calc_index_idis(deaths,two_pop_daly,total_pops))
np.savetxt('min_abs_ineq_deaths_30.txt', deaths)   

plotting_fun2(deaths,total_pops)
# Out:
# Total deaths: 166.0
# Deaths: [  0.20847044   1.54539823   6.12030418   5.99260606 137.73806274
#    0.36173238   0.53926243   1.27227413   0.73456161  11.86187204]
# Inequity in deaths (bars): 2.668986004889188
# Inequity in deaths (diff): 9.09510360743493e-07
# Inequity in deaths (ID): 71.86902339300495
# YLLs: 364.9503744431302
# Inequity in YLLs (diff): 12.26892179083664
# Inequity in YLLs (ID): 77.2481332930744
# array([3.66882698, 0.9998767 , 1.0000255 , 0.99999046, 1.00000068,
#        1.00493329])

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(worker_ineq_mort_IDIS_30,[d for d in starting_points_ineq_mi_30])
out_ineq_mi_30 = np.array(output)

print(np.round(out_ineq_mi_30[np.argmin(out_ineq_mi_30[:,1]),:][0],2))
np.savetxt('worker_ineq_mi_30_sol.txt', out_ineq_mi_30[np.argmin(out_ineq_mi_30[:,1]),:][0])
# Out:
# [0.24 0.49 0.1  0.04 0.87 0.91 0.76 0.54]

# %%
sol_ineq_mi_30=np.loadtxt('worker_ineq_mi_30_sol.txt')

y0_new=y0_use.copy()
y0_new = y0_new.reshape(21,10)
y0_new[18] = np.zeros(10)
y0_new=y0_new.reshape(210)
p = sol_ineq_mi_30
y0_new=vaccinate_sus_y0(p,y0_new)
t = np.linspace(0,4*4*7,300)
sol=scipy.integrate.solve_ivp(lambda t,y:coronavirusEqs_with_vaccination_only(t,y, params),[0,4*4*7], y0_new, t_eval=t)
sol_plot=np.reshape(sol.y,(21,10,300))
deaths = sol_plot[18,:,-1]-deaths_from_curr_inf 
print("Total deaths:",np.round(sum(deaths)))
print("Deaths:",deaths)
print("Inequity in deaths (bars):", calc_death_bars(deaths,total_pops))
print("Inequity in deaths (diff):",calc_mort_diff(deaths,total_pops))
print("Inequity in deaths (ID):",calc_mort_idis(deaths,total_pops,total_pops_age))
print("YLLs:",sum(calc_ylls(deaths,two_pop_daly,total_pops),1))
print("Inequity in YLLs (diff):",calc_yll_diff(deaths,two_pop_daly,total_pops))
print("Inequity in YLLs (ID):",calc_index_idis(deaths,two_pop_daly,total_pops))
np.savetxt('min_id_ineq_deaths_30.txt', deaths)   

plotting_fun2(deaths,total_pops)
# Out:
# Total deaths: 208.0
# Deaths: [  0.20613357   1.29383138   3.75179828  35.70996271 148.13629841
#    0.35843525   0.45115287   0.77736439   4.37666826  12.75671229]
# Inequity in deaths (bars): 2.6808830183064445
# Inequity in deaths (diff): 9.582733136308806e-07
# Inequity in deaths (ID): 72.18790546260875
# YLLs: 538.2843954559614
# Inequity in YLLs (diff): 14.447809086846805
# Inequity in YLLs (ID): 77.14937286106374
# array([3.67659936, 0.99915471, 0.99675528, 0.99985631, 0.99995004,
#        1.00377094])

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(worker_both_bars_30,[d for d in starting_points_bb_30])
out_bb_30 = np.array(output)

print(np.round(out_bb_30[np.argmin(out_bb_30[:,1]),:][0],2))
np.savetxt('worker_bb_30_sol.txt', out_bb_30[np.argmin(out_bb_30[:,1]),:][0])
# Out:
# [0.01 0.02 0.75 1.   0.64 0.82 0.93 1.  ]

# %%
sol_bb_30=np.loadtxt('worker_bb_30_sol.txt')
y0_new=y0_use.copy()
y0_new = y0_new.reshape(21,10)
y0_new[18] = np.zeros(10)
y0_new=y0_new.reshape(210)
p = sol_bb_30
y0_new=vaccinate_sus_y0(p,y0_new)
t = np.linspace(0,4*4*7,300)
sol=scipy.integrate.solve_ivp(lambda t,y:coronavirusEqs_with_vaccination_only(t,y, params),[0,4*4*7], y0_new, t_eval=t)
sol_plot=np.reshape(sol.y,(21,10,300))
deaths = sol_plot[18,:,-1]-deaths_from_curr_inf 
print("Total deaths:",np.round(sum(deaths)))
print("Deaths:",deaths)
print("Inequity in deaths (bars):", calc_death_bars(deaths,total_pops))
print("Inequity in deaths (diff):",calc_mort_diff(deaths,total_pops))
print("Inequity in deaths (ID):",calc_mort_idis(deaths,total_pops,total_pops_age))
print("YLLs:",sum(calc_ylls(deaths,two_pop_daly,total_pops),1))
print("Inequity in YLLs (diff):",calc_yll_diff(deaths,two_pop_daly,total_pops))
print("Inequity in YLLs (ID):",calc_index_idis(deaths,two_pop_daly,total_pops))
np.savetxt('min_rel_both_deaths_30.txt', deaths)   
     
plotting_fun2(deaths,total_pops)
# Out:
# Total deaths: 23.0
# Deaths: [2.15720265e-01 1.84625477e+00 7.76241200e+00 9.02501333e+00
#  1.65171357e-07 3.75214250e-01 1.37400249e+00 1.55500353e+00
#  1.10609066e+00 3.29837189e-08]
# Inequity in deaths (bars): 5.165430068469443
# Inequity in deaths (diff): 3.3502782365750674e-06
# Inequity in deaths (ID): 177.3156457930712
# YLLs: 179.11522205165573
# Inequity in YLLs (diff): 16.120337448019594
# Inequity in YLLs (ID): 183.80481425765882
# array([3.67766955, 2.13246829, 0.9636916 , 0.99983016, 2.31881398,
#        1.1491857 ])

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(worker_both_mort_30,[d for d in starting_points_bm_30])
out_bm_30 = np.array(output)

print(np.round(out_bm_30[np.argmin(out_bm_30[:,1]),:][0],2))
np.savetxt('worker_bm_30_sol.txt', out_bm_30[np.argmin(out_bm_30[:,1]),:][0])
# Out:
# [0.   0.39 1.   1.   0.   0.89 1.   1.  ]

# %%
sol_bm_30 = np.loadtxt('worker_bm_30_sol.txt')

y0_new=y0_use.copy()
y0_new = y0_new.reshape(21,10)
y0_new[18] = np.zeros(10)
y0_new=y0_new.reshape(210)
p = sol_bm_30
y0_new=vaccinate_sus_y0(p,y0_new)
t = np.linspace(0,4*4*7,300)
sol=scipy.integrate.solve_ivp(lambda t,y:coronavirusEqs_with_vaccination_only(t,y, params),[0,4*4*7], y0_new, t_eval=t)
sol_plot=np.reshape(sol.y,(21,10,300))
deaths = sol_plot[18,:,-1]-deaths_from_curr_inf 
print("Total deaths:",np.round(sum(deaths)))
print("Deaths:",deaths)
print("Inequity in deaths (bars):", calc_death_bars(deaths,total_pops))
print("Inequity in deaths (diff):",calc_mort_diff(deaths,total_pops))
print("Inequity in deaths (ID):",calc_mort_idis(deaths,total_pops,total_pops_age))
print("YLLs:",sum(calc_ylls(deaths,two_pop_daly,total_pops),1))
print("Inequity in YLLs (diff):",calc_yll_diff(deaths,two_pop_daly,total_pops))
print("Inequity in YLLs (ID):",calc_index_idis(deaths,two_pop_daly,total_pops))
np.savetxt('min_abs_both_deaths_30.txt', deaths)   
    
plotting_fun2(deaths,total_pops)
# Out:
# Total deaths: 11.0
# Deaths: [2.09811800e-01 1.77382099e+00 4.36567737e+00 6.65960070e-05
#  1.58486883e-05 3.72704894e-01 3.83298676e+00 9.07505494e-01
#  1.55589319e-09 3.45332865e-08]
# Inequity in deaths (bars): 9.922219296763823
# Inequity in deaths (diff): 8.553855473744309e-06
# Inequity in deaths (ID): 292.82622074451916
# YLLs: 110.73983455864027
# Inequity in YLLs (diff): 41.51412849915247
# Inequity in YLLs (ID): 295.90214349471984
# array([3.75594749e+00, 6.19176154e+00, 1.00000233e+00, 1.90596513e-04,
#        2.53014619e-02, 2.66451635e+00])

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(worker_both_mort_IDIS_30,[d for d in starting_points_bi_30])
out_bi_30 = np.array(output)

print(np.round(out_bi_30[np.argmin(out_bi_30[:,1]),:][0],2))
np.savetxt('worker_bi_30_sol.txt', out_bi_30[np.argmin(out_bi_30[:,1]),:][0])
# Out:
# [0.01 0.08 0.46 0.95 0.83 0.83 0.86 0.98]

# %%
sol_bi_30 = np.loadtxt('worker_bi_30_sol.txt')
y0_new=y0_use.copy()
y0_new = y0_new.reshape(21,10)
y0_new[18] = np.zeros(10)
y0_new=y0_new.reshape(210)
p = sol_bi_30
y0_new=vaccinate_sus_y0(p,y0_new)
t = np.linspace(0,4*4*7,300)
sol=scipy.integrate.solve_ivp(lambda t,y:coronavirusEqs_with_vaccination_only(t,y, params),[0,4*4*7], y0_new, t_eval=t)
sol_plot=np.reshape(sol.y,(21,10,300))
deaths = sol_plot[18,:,-1]-deaths_from_curr_inf 
print("Total deaths:",np.round(sum(deaths)))
print("Deaths:",deaths)
print("Inequity in deaths (bars):", calc_death_bars(deaths,total_pops))
print("Inequity in deaths (diff):",calc_mort_diff(deaths,total_pops))
print("Inequity in deaths (ID):",calc_mort_idis(deaths,total_pops,total_pops_age))
print("YLLs:",sum(calc_ylls(deaths,two_pop_daly,total_pops),1))
print("Inequity in YLLs (diff):",calc_yll_diff(deaths,two_pop_daly,total_pops))
print("Inequity in YLLs (ID):",calc_index_idis(deaths,two_pop_daly,total_pops))
np.savetxt('min_id_both_deaths_30.txt', deaths)   
plotting_fun2(deaths,total_pops)
# Out:
# Total deaths: 41.0
# Deaths: [ 0.21630061  1.85020762  7.38937696 20.01619898  5.80503019  0.37419795
#   0.6517223   1.53500193  2.44746135  0.50499775]
# Inequity in deaths (bars): 2.6805072190486023
# Inequity in deaths (diff): 1.200161757597572e-06
# Inequity in deaths (ID): 72.83234362451532
# YLLs: 246.95604638695957
# Inequity in YLLs (diff): 8.957762785952875
# Inequity in YLLs (ID): 77.92896488637932
# array([3.65786767, 1.00931983, 0.99931979, 0.99751077, 1.01015028,
#        1.02152435])

# %% [markdown]
# # Working with YLLs

# %%
from YLL_funs import *

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(sp_ylls_30,[d for d in ref_dirs_10k_30p])
out = np.array(output)
idx = out.argsort()[:20]
starting_points_ylls_30 = ref_dirs_10k_30p[idx]
starting_points_ylls_30 = np.append(starting_points_ylls_30,sp_1).reshape(21,8)
starting_points_ylls_30 = np.append(starting_points_ylls_30,sp_2).reshape(22,8)
starting_points_ylls_30 = np.append(starting_points_ylls_30,sp_3).reshape(23,8)
starting_points_ylls_30 = np.append(starting_points_ylls_30,sp_4).reshape(24,8)
np.savetxt('starting_points_ylls_30p.txt', starting_points_ylls_30)

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(sp_ineq_ylls_30,[d for d in ref_dirs_10k_30p])
out = np.array(output)
idx = out.argsort()[:20]
starting_points_iy_30 = ref_dirs_10k_30p[idx]
starting_points_iy_30 = np.append(starting_points_iy_30,sp_1).reshape(21,8)
starting_points_iy_30 = np.append(starting_points_iy_30,sp_2).reshape(22,8)
starting_points_iy_30 = np.append(starting_points_iy_30,sp_3).reshape(23,8)
starting_points_iy_30 = np.append(starting_points_iy_30,sp_4).reshape(24,8)
np.savetxt('starting_points_ineq_ylls_30p.txt', starting_points_iy_30)

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(sp_ineq_idis_30,[d for d in ref_dirs_10k_30p])
out = np.array(output)
idx = out.argsort()[:20]
starting_points_idis_30 = ref_dirs_10k_30p[idx]
starting_points_idis_30 = np.append(starting_points_idis_30,sp_1).reshape(21,8)
starting_points_idis_30 = np.append(starting_points_idis_30,sp_2).reshape(22,8)
starting_points_idis_30 = np.append(starting_points_idis_30,sp_3).reshape(23,8)
starting_points_idis_30 = np.append(starting_points_idis_30,sp_4).reshape(24,8)
np.savetxt('starting_points_ineq_yll_idis_30p.txt', starting_points_idis_30)

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(sp_both_ylls_30,[d for d in ref_dirs_10k_30p])
out = np.array(output)
idx = out.argsort()[:20]
starting_points_by_30 = ref_dirs_10k_30p[idx]
starting_points_by_30 = np.append(starting_points_by_30,sp_1).reshape(21,8)
starting_points_by_30 = np.append(starting_points_by_30,sp_2).reshape(22,8)
starting_points_by_30 = np.append(starting_points_by_30,sp_3).reshape(23,8)
starting_points_by_30 = np.append(starting_points_by_30,sp_4).reshape(24,8)
np.savetxt('starting_points_both_ylls_30p.txt', starting_points_by_30)

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(sp_both_idis_30,[d for d in ref_dirs_10k_30p])
out = np.array(output)
idx = out.argsort()[:20]
starting_points_byi_30 = ref_dirs_10k_30p[idx]
starting_points_byi_30 = np.append(starting_points_byi_30,sp_1).reshape(21,8)
starting_points_byi_30 = np.append(starting_points_byi_30,sp_2).reshape(22,8)
starting_points_byi_30 = np.append(starting_points_byi_30,sp_3).reshape(23,8)
starting_points_byi_30 = np.append(starting_points_byi_30,sp_4).reshape(24,8)
np.savetxt('starting_points_both_ylls_idis_30p.txt', starting_points_byi_30)

# %%
starting_points_ylls_30  = np.loadtxt('starting_points_ylls_30p.txt')
starting_points_ineq_ylls_30 =np.loadtxt('starting_points_ineq_ylls_30p.txt')
starting_points_ineq_ylls_idis_30  = np.loadtxt('starting_points_ineq_yll_idis_30p.txt')
starting_points_by_30 = np.loadtxt('starting_points_both_ylls_30p.txt')
starting_points_byi_30 = np.loadtxt('starting_points_both_ylls_idis_30p.txt')

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(worker_ylls_30,[d for d in starting_points_ylls_30])
out_yll_30 = np.array(output)

print(np.round(out_yll_30[np.argmin(out_yll_30[:,1]),:][0],2))
np.savetxt('yll_30_sol.txt', out_yll_30[np.argmin(out_yll_30[:,1]),:][0])
# Out:
# [0.   0.36 1.   1.   0.   1.   1.   1.  ]

# %%
sol_yll_30 = np.loadtxt('yll_30_sol.txt')

y0_new=y0_use.copy()
y0_new = y0_new.reshape(21,10)
y0_new[18] = np.zeros(10)
y0_new=y0_new.reshape(210)
p = sol_yll_30
y0_new=vaccinate_sus_y0(p,y0_new)
t = np.linspace(0,4*4*7,300)
sol=scipy.integrate.solve_ivp(lambda t,y:coronavirusEqs_with_vaccination_only(t,y, params),[0,4*4*7], y0_new, t_eval=t)
sol_plot=np.reshape(sol.y,(21,10,300))
deaths = sol_plot[18,:,-1]-deaths_from_curr_inf 
print("Total deaths:",np.round(sum(deaths)))
print("Deaths:",deaths)
print("Inequity in deaths (bars):", calc_death_bars(deaths,total_pops))
print("Inequity in deaths (diff):",calc_mort_diff(deaths,total_pops))
print("Inequity in deaths (ID):",calc_mort_idis(deaths,total_pops,total_pops_age))
print("YLLs:",sum(calc_ylls(deaths,two_pop_daly,total_pops),1))
print("Inequity in YLLs (diff):",calc_yll_diff(deaths,two_pop_daly,total_pops))
print("Inequity in YLLs (ID):",calc_index_idis(deaths,two_pop_daly,total_pops))
np.savetxt('min_ylls_30.txt', deaths)   
    
sum(abs(plotting_fun2(deaths,total_pops)-1))
# Out:
# Total deaths: 11.0
# Deaths: [2.09296208e-01 1.76788726e+00 4.50774225e+00 3.65999514e-05
#  3.30784129e-03 3.71375069e-01 3.80791084e+00 3.70738995e-11
#  1.80691551e-09 3.39548603e-08]
# Inequity in deaths (bars): 10.923143996714188
# Inequity in deaths (diff): 1.9315082053565122e-05
# Inequity in deaths (ID): 354.44825928792966
# YLLs: 85.55434060544948
# Inequity in YLLs (diff): 66.94994177313473
# Inequity in YLLs (ID): 356.62186945584784
# 11.873107817820259

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(worker_ineq_ylls_30,[d for d in starting_points_ineq_ylls_30 ])
out_iy_30 = np.array(output)

print(np.round(out_iy_30[np.argmin(out_iy_30[:,1]),:][0],2))
np.savetxt('ineq_yll_30_sol.txt', out_iy_30[np.argmin(out_iy_30[:,1]),:][0])
# Out:
# [0.05 1.   0.57 0.   0.84 1.   0.89 0.55]

# %%
sol_iy_30 = np.loadtxt('ineq_yll_30_sol.txt')

y0_new=y0_use.copy()
y0_new = y0_new.reshape(21,10)
y0_new[18] = np.zeros(10)
y0_new=y0_new.reshape(210)
p = sol_iy_30
y0_new=vaccinate_sus_y0(p,y0_new)
t = np.linspace(0,4*4*7,300)
sol=scipy.integrate.solve_ivp(lambda t,y:coronavirusEqs_with_vaccination_only(t,y, params),[0,4*4*7], y0_new, t_eval=t)
sol_plot=np.reshape(sol.y,(21,10,300))
deaths = sol_plot[18,:,-1]-deaths_from_curr_inf 
print("Total deaths:",np.round(sum(deaths)))
print("Deaths:",deaths)
print("Inequity in deaths (bars):", calc_death_bars(deaths,total_pops))
print("Inequity in deaths (diff):",calc_mort_diff(deaths,total_pops))
print("Inequity in deaths (ID):",calc_mort_idis(deaths,total_pops,total_pops_age))
print("YLLs:",sum(calc_ylls(deaths,two_pop_daly,total_pops),1))
print("Inequity in YLLs (diff):",calc_yll_diff(deaths,two_pop_daly,total_pops))
print("Inequity in YLLs (ID):",calc_index_idis(deaths,two_pop_daly,total_pops))
np.savetxt('min_abs_ineq_ylls_30.txt', deaths)   
       
    
sum(abs(plotting_fun2(deaths,total_pops)-1))
# Out:
# Total deaths: 156.0
# Deaths: [1.88929119e-01 1.41404914e+00 1.24628085e-03 1.35767201e+01
#  1.27693767e+02 3.29165514e-01 4.80962145e-01 2.22167188e-04
#  1.62506717e+00 1.05487329e+01]
# Inequity in deaths (bars): 2.915929214968446
# Inequity in deaths (diff): 1.2824658086727986e-05
# Inequity in deaths (ID): 83.87994911334302
# YLLs: 316.2818591888465
# Inequity in YLLs (diff): 5.726389293700171
# Inequity in YLLs (ID): 78.69383441931996
# 2.9499549465269133

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(worker_ineq_ylls_idis_30,[d for d in starting_points_ineq_ylls_idis_30])
out_iyi_30 = np.array(output)

print(np.round(out_iyi_30[np.argmin(out_iyi_30[:,1]),:][0],2))
np.savetxt('ineq_yll_idis_30_sol.txt', out_iyi_30[np.argmin(out_iyi_30[:,1]),:][0])
# Out:
# [0.17 0.33 0.42 0.4  0.56 0.63 0.43 0.33]

# %%
sol_iyi_30 = np.loadtxt('ineq_yll_idis_30_sol.txt')

y0_new=y0_use.copy()
y0_new = y0_new.reshape(21,10)
y0_new[18] = np.zeros(10)
y0_new=y0_new.reshape(210)
p = sol_iyi_30
y0_new=vaccinate_sus_y0(p,y0_new)
t = np.linspace(0,4*4*7,300)
sol=scipy.integrate.solve_ivp(lambda t,y:coronavirusEqs_with_vaccination_only(t,y, params),[0,4*4*7], y0_new, t_eval=t)
sol_plot=np.reshape(sol.y,(21,10,300))
deaths = sol_plot[18,:,-1]-deaths_from_curr_inf 
print("Total deaths:",np.round(sum(deaths)))
print("Deaths:",deaths)
print("Inequity in deaths (bars):", calc_death_bars(deaths,total_pops))
print("Inequity in deaths (diff):",calc_mort_diff(deaths,total_pops))
print("Inequity in deaths (ID):",calc_mort_idis(deaths,total_pops,total_pops_age))
print("YLLs:",sum(calc_ylls(deaths,two_pop_daly,total_pops),1))
print("Inequity in YLLs (diff):",calc_yll_diff(deaths,two_pop_daly,total_pops))
print("Inequity in YLLs (ID):",calc_index_idis(deaths,two_pop_daly,total_pops))
np.savetxt('min_id_ineq_ylls_30.txt', deaths)   
          
sum(abs(plotting_fun2(deaths,total_pops)-1))
# Out:
# Total deaths: 155.0
# Deaths: [ 0.21740783  1.54127011  5.28917143 22.85153915 88.24441098  0.38237166
#   1.72611011  3.51824038 11.31208536 19.86159406]
# Inequity in deaths (bars): 11.779661065245913
# Inequity in deaths (diff): 0.0004897412020223747
# Inequity in deaths (ID): 408.2514962892126
# YLLs: 800.6253501801114
# Inequity in YLLs (diff): 435.3078560631779
# Inequity in YLLs (ID): 420.03316675218264
# 13.71472317245031

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(worker_both_30,[d for d in starting_points_by_30])
out_by_30 = np.array(output)

print(np.round(out_by_30[np.argmin(out_by_30[:,1]),:][0],2))
np.savetxt('both_yll_30_sol.txt', out_by_30[np.argmin(out_by_30[:,1]),:][0])
# Out:
# [0.   0.   1.   0.61 0.83 0.81 1.   0.83]

# %%
sol_by_30 = np.loadtxt('both_yll_30_sol.txt')

y0_new=y0_use.copy()
y0_new = y0_new.reshape(21,10)
y0_new[18] = np.zeros(10)
y0_new=y0_new.reshape(210)
p = sol_by_30
y0_new=vaccinate_sus_y0(p,y0_new)
t = np.linspace(0,4*4*7,300)
sol=scipy.integrate.solve_ivp(lambda t,y:coronavirusEqs_with_vaccination_only(t,y, params),[0,4*4*7], y0_new, t_eval=t)
sol_plot=np.reshape(sol.y,(21,10,300))
deaths = sol_plot[18,:,-1]-deaths_from_curr_inf 
print("Total deaths:",np.round(sum(deaths)))
print("Deaths:",deaths)
print("Inequity in deaths (bars):", calc_death_bars(deaths,total_pops))
print("Inequity in deaths (diff):",calc_mort_diff(deaths,total_pops))
print("Inequity in deaths (ID):",calc_mort_idis(deaths,total_pops,total_pops_age))
print("YLLs:",sum(calc_ylls(deaths,two_pop_daly,total_pops),1))
print("Inequity in YLLs (diff):",calc_yll_diff(deaths,two_pop_daly,total_pops))
print("Inequity in YLLs (ID):",calc_index_idis(deaths,two_pop_daly,total_pops))
np.savetxt('min_abs_both_ylls_30.txt', deaths)   
       
sum(abs(plotting_fun2(deaths,total_pops)-1))
# Out:
# Total deaths: 63.0
# Deaths: [2.11986314e-01 1.80986010e+00 7.75700687e+00 4.60139583e-05
#  4.64740281e+01 3.66883645e-01 6.15615857e-01 1.58736132e+00
#  5.39176241e-06 3.83926591e+00]
# Inequity in deaths (bars): 2.785078781745308
# Inequity in deaths (diff): 5.351661851402136e-06
# Inequity in deaths (ID): 78.03730727292125
# YLLs: 192.0659062027396
# Inequity in YLLs (diff): 6.362307762909115
# Inequity in YLLs (ID): 72.80264738783917
# 2.807978372431865

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(worker_both_idis_30,[d for d in starting_points_byi_30])
out_byi_30 = np.array(output)

print(np.round(out_byi_30[np.argmin(out_byi_30[:,1]),:][0],2))
np.savetxt('both_yll_idis_30_sol.txt', out_byi_30[np.argmin(out_byi_30[:,1]),:][0])
# Out:
# [0.   0.01 0.99 0.61 0.83 0.82 1.   0.83]

# %%
sol_byi_30 = np.loadtxt('both_yll_idis_30_sol.txt')

y0_new=y0_use.copy()
y0_new = y0_new.reshape(21,10)
y0_new[18] = np.zeros(10)
y0_new=y0_new.reshape(210)
p = sol_byi_30
y0_new=vaccinate_sus_y0(p,y0_new)
t = np.linspace(0,4*4*7,300)
sol=scipy.integrate.solve_ivp(lambda t,y:coronavirusEqs_with_vaccination_only(t,y, params),[0,4*4*7], y0_new, t_eval=t)
sol_plot=np.reshape(sol.y,(21,10,300))
deaths = sol_plot[18,:,-1]-deaths_from_curr_inf 
print("Total deaths:",np.round(sum(deaths)))
print("Deaths:",deaths)
print("Inequity in deaths (bars):", calc_death_bars(deaths,total_pops))
print("Inequity in deaths (diff):",calc_mort_diff(deaths,total_pops))
print("Inequity in deaths (ID):",calc_mort_idis(deaths,total_pops,total_pops_age))
print("YLLs:",sum(calc_ylls(deaths,two_pop_daly,total_pops),1))
print("Inequity in YLLs (diff):",calc_yll_diff(deaths,two_pop_daly,total_pops))
print("Inequity in YLLs (ID):",calc_index_idis(deaths,two_pop_daly,total_pops))
np.savetxt('min_id_both_ylls_30.txt', deaths)   
    
sum(abs(plotting_fun2(deaths,total_pops)-1))
# Out:
# Total deaths: 63.0
# Deaths: [2.11704228e-01 1.80588651e+00 7.66116492e+00 1.88131086e-01
#  4.68594901e+01 3.66420485e-01 6.14363947e-01 1.56781423e+00
#  2.25207165e-02 3.87162222e+00]
# Inequity in deaths (bars): 2.7643553089691673
# Inequity in deaths (diff): 5.376472231701836e-06
# Inequity in deaths (ID): 76.98445658378368
# YLLs: 192.71836378792116
# Inequity in YLLs (diff): 6.3625273007718715
# Inequity in YLLs (ID): 71.74436846552067
# 2.787289972529476
