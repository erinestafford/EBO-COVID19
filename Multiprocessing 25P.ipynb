# %%
import numpy as np
import scipy
import matplotlib.pylab as plt
from matplotlib.pyplot import figure
from scipy.integrate import odeint
from scipy.optimize import minimize
import pickle
from timeit import default_timer as timer
import sys, getopt
import time
import csv
import multiprocessing as mp
from multiprocessing import Pool
import os
import pandas as pd
from scipy.optimize import Bounds

# %%
from two_pop_params_current import *
from init_cond_current import *

# %%
from coronavirusEqs import *
from ineq_measures_alone import *
from plotting_fn import *
from deaths_25 import *

# %%
ref_dirs_10k_25p = np.zeros((10000,8))
for i in range(10000):
    it = 0
    test=np.random.rand(8)
    while (test[0:4]@y0_use[1:5]+test[4:]@y0_use[6:10])>0.25*N:
        test=np.random.rand(8)
    ref_dirs_10k_25p[i,:]=test
np.savetxt('ref_dirs_10k_25p.txt', ref_dirs_10k_25p)
ref_dirs_10k_25p=np.loadtxt('ref_dirs_10k_25p.txt')

# %%
def check_constraint(p,pops):
    return (p[0:4]@pops[1:5]+p[4:]@pops[6:10])<0.25*N

# %% [markdown]
# # 25 % Cost Constraint (deaths)

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(sp_death_25,[d for d in ref_dirs_10k_25p])
out = np.array(output)
idx = out.argsort()[:20]
starting_points_d25_01 = ref_dirs_10k_25p[idx]
sp_1 = np.array([0,0,0,0.9,1,1,1,1])
sp_2 = np.array([0,0,1,1,0,0.3,1,1])
sp_3 = np.array([0, 0, 0.8, 1, 0, 1, 1, 1])
sp_4 = np.array([0, 0.2, 1, 1, 0, 0, 0, 0])
starting_points_d25_01 = np.append(starting_points_d25_01,sp_1).reshape(21,8)
starting_points_d25_01 = np.append(starting_points_d25_01,sp_2).reshape(22,8)
starting_points_d25_01 = np.append(starting_points_d25_01,sp_3).reshape(23,8)
starting_points_d25_01 = np.append(starting_points_d25_01,sp_4).reshape(24,8)
np.savetxt('starting_points_25p_combo0_death.txt', starting_points_d25_01)

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(sp_ineq_bars_25,[d for d in ref_dirs_10k_25p])
out = np.array(output)
idx = out.argsort()[:20]
starting_points_d25_20 = ref_dirs_10k_25p[idx]
sp_1 = np.array([0,0,0,0.9,1,1,1,1])
sp_2 = np.array([0,0,1,1,0,0.3,1,1])
sp_3 = np.array([0, 0, 0.8, 1, 0, 1, 1, 1])
sp_4 = np.array([0, 0.2, 1, 1, 0, 0, 0, 0])
starting_points_d25_20 = np.append(starting_points_d25_20,sp_1).reshape(21,8)
starting_points_d25_20 = np.append(starting_points_d25_20,sp_2).reshape(22,8)
starting_points_d25_20 = np.append(starting_points_d25_20,sp_3).reshape(23,8)
starting_points_d25_20 = np.append(starting_points_d25_20,sp_4).reshape(24,8)
np.savetxt('starting_points_25p_combo0_ineq_bars.txt', starting_points_d25_20)

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(sp_ineq_mort_25,[d for d in ref_dirs_10k_25p])
out = np.array(output)
idx = out.argsort()[:20]
starting_points_d25_20 = ref_dirs_10k_25p[idx]
sp_1 = np.array([0,0,0,0.9,1,1,1,1])
sp_2 = np.array([0,0,1,1,0,0.3,1,1])
sp_3 = np.array([0, 0, 0.8, 1, 0, 1, 1, 1])
sp_4 = np.array([0, 0.2, 1, 1, 0, 0, 0, 0])
starting_points_d25_20 = np.append(starting_points_d25_20,sp_1).reshape(21,8)
starting_points_d25_20 = np.append(starting_points_d25_20,sp_2).reshape(22,8)
starting_points_d25_20 = np.append(starting_points_d25_20,sp_3).reshape(23,8)
starting_points_d25_20 = np.append(starting_points_d25_20,sp_4).reshape(24,8)
np.savetxt('starting_points_25p_combo0_ineq_mort.txt', starting_points_d25_20)

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(sp_ineq_mort_IDIS_25,[d for d in ref_dirs_10k_25p])
out = np.array(output)
idx = out.argsort()[:20]
starting_points_ineq_mi_25 = ref_dirs_10k_25p[idx]
sp_1 = np.array([0,0,0,0.9,1,1,1,1])
sp_2 = np.array([0,0,1,1,0,0.3,1,1])
sp_3 = np.array([0, 0, 0.8, 1, 0, 1, 1, 1])
sp_4 = np.array([0, 0.2, 1, 1, 0, 0, 0, 0])
starting_points_ineq_mi_25 = np.append(starting_points_ineq_mi_25,sp_1).reshape(21,8)
starting_points_ineq_mi_25 = np.append(starting_points_ineq_mi_25,sp_2).reshape(22,8)
starting_points_ineq_mi_25 = np.append(starting_points_ineq_mi_25,sp_3).reshape(23,8)
starting_points_ineq_mi_25 = np.append(starting_points_ineq_mi_25,sp_4).reshape(24,8)
np.savetxt('starting_points_25p_combo0_ineq_mi.txt', starting_points_ineq_mi_25)

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(sp_both_bars_25,[d for d in ref_dirs_10k_25p])
out = np.array(output)
idx = out.argsort()[:20]
starting_points_bb_25 = ref_dirs_10k_25p[idx]
sp_1 = np.array([0,0,0,0.9,1,1,1,1])
sp_2 = np.array([0,0,1,1,0,0.3,1,1])
sp_3 = np.array([0, 0, 0.8, 1, 0, 1, 1, 1])
sp_4 = np.array([0, 0.2, 1, 1, 0, 0, 0, 0])
starting_points_bb_25 = np.append(starting_points_bb_25,sp_2).reshape(21,8)
starting_points_bb_25 = np.append(starting_points_bb_25,sp_3).reshape(22,8)
starting_points_bb_25 = np.append(starting_points_bb_25,sp_4).reshape(23,8)
starting_points_bb_25 = np.append(starting_points_bb_25,sp_1).reshape(24,8)
np.savetxt('starting_points_25p_combo0_bb.txt', starting_points_bb_25)

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(sp_both_mort_25,[d for d in ref_dirs_10k_25p])
out = np.array(output)
idx = out.argsort()[:20]
starting_points_bm_25 = ref_dirs_10k_25p[idx]
sp_1 = np.array([0,0,0,0.9,1,1,1,1])
sp_2 = np.array([0,0,1,1,0,0.3,1,1])
sp_3 = np.array([0, 0, 0.8, 1, 0, 1, 1, 1])
sp_4 = np.array([0, 0.2, 1, 1, 0, 0, 0, 0])
starting_points_bm_25 = np.append(starting_points_bm_25,sp_2).reshape(21,8)
starting_points_bm_25 = np.append(starting_points_bm_25,sp_3).reshape(22,8)
starting_points_bm_25 = np.append(starting_points_bm_25,sp_4).reshape(23,8)
starting_points_bm_25 = np.append(starting_points_bm_25,sp_1).reshape(24,8)
np.savetxt('starting_points_25p_combo0_bm.txt', starting_points_bm_25)

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(sp_both_mort_IDIS_25,[d for d in ref_dirs_10k_25p])
out = np.array(output)
idx = out.argsort()[:20]
starting_points_bi_25 = ref_dirs_10k_25p[idx]
sp_1 = np.array([0,0,0,0.9,1,1,1,1])
sp_2 = np.array([0,0,1,1,0,0.3,1,1])
sp_3 = np.array([0, 0, 0.8, 1, 0, 1, 1, 1])
sp_4 = np.array([0, 0.2, 1, 1, 0, 0, 0, 0])
starting_points_bi_25 = np.append(starting_points_bi_25,sp_2).reshape(21,8)
starting_points_bi_25 = np.append(starting_points_bi_25,sp_3).reshape(22,8)
starting_points_bi_25 = np.append(starting_points_bi_25,sp_4).reshape(23,8)
starting_points_bi_25 = np.append(starting_points_bi_25,sp_1).reshape(24,8)
np.savetxt('starting_points_25p_combo0_bi.txt', starting_points_bi_25)

# %%
starting_points_deaths_25  = np.loadtxt('starting_points_25p_combo0_death.txt')
starting_points_ineq_bars_25 = np.loadtxt('starting_points_25p_combo0_ineq_bars.txt')
starting_points_ineq_mort_25  = np.loadtxt('starting_points_25p_combo0_ineq_mort.txt')
starting_points_ineq_ai_25 = np.loadtxt('starting_points_25p_combo0_ineq_mi.txt')
starting_points_bb_25 = np.loadtxt('starting_points_25p_combo0_bb.txt')
starting_points_bm_25 = np.loadtxt('starting_points_25p_combo0_bm.txt')
starting_points_bi_25 = np.loadtxt('starting_points_25p_combo0_bi.txt')

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(worker_death_25,[d for d in starting_points_deaths_25])
out01 = np.array(output)

print(np.round(out01[np.argmin(out01[:,1]),:][0],2))
np.savetxt('worker_death_25_sol.txt', out01[np.argmin(out01[:,1]),:][0])
# Out:
# [0.   0.   0.88 1.   0.   1.   1.   1.  ]

# %%
sol_d25 = np.loadtxt('worker_death_25_sol.txt')

y0_new=y0_use.copy()
y0_new = y0_new.reshape(21,10)
y0_new[18] = np.zeros(10)
y0_new=y0_new.reshape(210)
p = sol_d25
y0_new=vaccinate_sus_y0(p,y0_new)
t = np.linspace(0,4*4*7,300)
sol=scipy.integrate.solve_ivp(lambda t,y:coronavirusEqs_with_vaccination_only(t,y, params),[0,4*4*7], y0_new, t_eval=t)
sol_plot=np.reshape(sol.y,(21,10,300))
deaths = sol_plot[18,:,-1]-deaths_from_curr_inf 
print(np.round(sum(deaths)))
print(deaths)
np.savetxt('min_deaths_25.txt', deaths)
sum(abs(plotting_fun2(deaths,total_pops)-1))
# Out:
# 20.0
# [2.28860132e-01 2.02923257e+00 8.50261595e+00 4.57327723e+00
#  1.17670796e-05 4.04556036e-01 4.31598452e+00 1.25759403e-10
#  1.79746174e-09 3.07590966e-08]
# 10.830678660660515

# %%
starting_points_ineq_bars_25 = np.append(starting_points_ineq_bars_25,np.array([0.02, 0.52, 0.47, 0.3,  0.17, 0.31, 0.28, 0.35])).reshape(25,8)

if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(worker_ineq_bars_25,[d for d in starting_points_ineq_bars_25])
out_ineq_bars_25 = np.array(output)

print(np.round(out_ineq_bars_25[np.argmin(out_ineq_bars_25[:,1]),:][0],2))
np.savetxt('worker_ineq_bars_25_sol.txt', out_ineq_bars_25[np.argmin(out_ineq_bars_25[:,1]),:][0])
# Out:
# [0.01 0.28 0.48 0.36 0.83 0.86 0.86 0.7 ]

# %%
sol_ineq_bars_25=np.loadtxt('worker_ineq_bars_25_sol.txt')

y0_new=y0_use.copy()
y0_new = y0_new.reshape(21,10)
y0_new[18] = np.zeros(10)
y0_new=y0_new.reshape(210)
p = sol_ineq_bars_25
y0_new=vaccinate_sus_y0(p,y0_new)
t = np.linspace(0,4*4*7,300)
sol=scipy.integrate.solve_ivp(lambda t,y:coronavirusEqs_with_vaccination_only(t,y, params),[0,4*4*7], y0_new, t_eval=t)
sol_plot=np.reshape(sol.y,(21,10,300))
deaths = sol_plot[18,:,-1]-deaths_from_curr_inf 
print(np.round(sum(deaths)))
print(deaths)
np.savetxt('min_rel_ineq_deaths_25.txt', deaths)
sum(abs(plotting_fun2(np.round(deaths,2),total_pops)-1))
# Out:
# 130.0
# [ 0.21575195  1.82898749  5.68078285 19.98559921 89.53268669  0.3735749
#   0.64102599  1.18226785  2.4498373   7.7073071 ]
# 2.565269323008539

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(worker_ineq_mort_25,[d for d in starting_points_ineq_mort_25])
out_ineq_mort_25 = np.array(output)

print(np.round(out_ineq_mort_25[np.argmin(out_ineq_mort_25[:,1]),:][0],2))
np.savetxt('worker_ineq_mort_25_sol.txt', out_ineq_mort_25[np.argmin(out_ineq_mort_25[:,1]),:][0])
# Out:
# [0.09 0.08 0.56 0.02 0.84 0.83 0.88 0.53]

# %%
sol_ineq_mort_25=np.loadtxt('worker_ineq_mort_25_sol.txt')

y0_new=y0_use.copy()
y0_new = y0_new.reshape(21,10)
y0_new[18] = np.zeros(10)
y0_new=y0_new.reshape(210)
p = sol_ineq_mort_25
y0_new=vaccinate_sus_y0(p,y0_new)
t = np.linspace(0,4*4*7,300)
sol=scipy.integrate.solve_ivp(lambda t,y:coronavirusEqs_with_vaccination_only(t,y, params),[0,4*4*7], y0_new, t_eval=t)
sol_plot=np.reshape(sol.y,(21,10,300))
deaths = sol_plot[18,:,-1]-deaths_from_curr_inf
print(np.round(sum(deaths)))
print(deaths)
np.savetxt('min_abs_ineq_deaths_25.txt', deaths)
plotting_fun2(deaths,total_pops)
# Out:
# 203.0
# [  0.22329108   1.75307522   7.82564089  18.20990603 156.82631899
#    0.38644195   0.61169537   1.61684383   2.2344907   13.50472697]
# array([3.65929327, 0.99981888, 0.99392026, 1.0010464 , 0.99992606,
#        1.00406826])

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(worker_ineq_mort_IDIS_25,[d for d in starting_points_ineq_mi_25])
out_ineq_mi_25 = np.array(output)

print(np.round(out_ineq_mi_25[np.argmin(out_ineq_mi_25[:,1]),:][0],2))
np.savetxt('worker_ineq_mi_25_sol.txt', out_ineq_mi_25[np.argmin(out_ineq_mi_25[:,1]),:][0])
# Out:
# [0.01 0.24 0.09 0.42 0.83 0.86 0.75 0.72]

# %%
sol_ineq_mi_25=np.loadtxt('worker_ineq_mi_25_sol.txt')

y0_new=y0_use.copy()
y0_new = y0_new.reshape(21,10)
y0_new[18] = np.zeros(10)
y0_new=y0_new.reshape(210)
p = sol_ineq_mi_25
y0_new=vaccinate_sus_y0(p,y0_new)
t = np.linspace(0,4*4*7,300)
sol=scipy.integrate.solve_ivp(lambda t,y:coronavirusEqs_with_vaccination_only(t,y, params),[0,4*4*7], y0_new, t_eval=t)
sol_plot=np.reshape(sol.y,(21,10,300))
deaths = sol_plot[18,:,-1]-deaths_from_curr_inf 
print(np.round(sum(deaths)))
print(deaths)
np.savetxt('min_id_ineq_deaths_25.txt', deaths)
plotting_fun2(deaths,total_pops)
# Out:
# 155.0
# [ 0.22845643  1.97783523  6.63907282 39.99994083 90.80353304  0.39482652
#   0.69246963  1.38030463  4.89541112  7.81655008]
# array([3.65415742, 1.00322262, 1.00016326, 0.99841979, 0.99957042,
#        1.00510981])

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(worker_both_bars_25,[d for d in starting_points_bb_25])
out_bb_25 = np.array(output)

print(np.round(out_bb_25[np.argmin(out_bb_25[:,1]),:][0],2))
np.savetxt('worker_bb_25_sol.txt', out_bb_25[np.argmin(out_bb_25[:,1]),:][0])
# Out:
# [0.   0.07 0.11 1.   0.82 0.82 0.85 1.  ]

# %%
sol_bb_25=np.loadtxt('worker_bb_25_sol.txt')
y0_new=y0_use.copy()
y0_new = y0_new.reshape(21,10)
y0_new[18] = np.zeros(10)
y0_new=y0_new.reshape(210)
p = sol_bb_25
y0_new=vaccinate_sus_y0(p,y0_new)
t = np.linspace(0,4*4*7,300)
sol=scipy.integrate.solve_ivp(lambda t,y:coronavirusEqs_with_vaccination_only(t,y, params),[0,4*4*7], y0_new, t_eval=t)
sol_plot=np.reshape(sol.y,(21,10,300))
deaths = sol_plot[18,:,-1]-deaths_from_curr_inf 
print(np.round(sum(deaths)))
print(deaths)
np.savetxt('min_rel_both_deaths_25.txt', deaths)
plotting_fun2(deaths,total_pops)
# Out:
# 53.0
# [2.26627088e-01 1.98941741e+00 8.13648894e+00 3.74262905e+01
#  1.63551107e-07 3.91300912e-01 7.04151935e-01 1.68658940e+00
#  2.86501835e+00 3.26782690e-08]
# array([3.65076071, 1.01420829, 0.99718494, 0.62450222, 2.32009936,
#        0.72874555])

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(worker_both_mort_25,[d for d in starting_points_bm_25])
out_bm_25 = np.array(output)

print(np.round(out_bm_25[np.argmin(out_bm_25[:,1]),:][0],2))
np.savetxt('worker_bm_25_sol.txt', out_bm_25[np.argmin(out_bm_25[:,1]),:][0])
# Out:
# [0.   0.   0.91 1.   0.   0.82 0.98 1.  ]

# %%
sol_bm_25 = np.loadtxt('worker_bm_25_sol.txt')

y0_new=y0_use.copy()
y0_new = y0_new.reshape(21,10)
y0_new[18] = np.zeros(10)
y0_new=y0_new.reshape(210)
p = sol_bm_25
y0_new=vaccinate_sus_y0(p,y0_new)
t = np.linspace(0,4*4*7,300)
sol=scipy.integrate.solve_ivp(lambda t,y:coronavirusEqs_with_vaccination_only(t,y, params),[0,4*4*7], y0_new, t_eval=t)
sol_plot=np.reshape(sol.y,(21,10,300))
deaths = sol_plot[18,:,-1]-deaths_from_curr_inf 
print(np.round(sum(deaths)))
print(deaths)
np.savetxt('min_abs_both_deaths_25.txt', deaths)
plotting_fun2(deaths,total_pops)
# Out:
# 21.0
# [2.31136542e-01 2.05854137e+00 8.64357378e+00 3.32445867e+00
#  1.76094679e-02 4.09330269e-01 4.39959893e+00 1.79675953e+00
#  4.07509359e-01 4.35912512e-03]
# array([3.74446328, 6.12407047, 1.        , 1.00000002, 2.87444585,
#        1.87813605])

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(worker_both_mort_IDIS_25,[d for d in starting_points_bi_25])
out_bi_25 = np.array(output)

print(np.round(out_bi_25[np.argmin(out_bi_25[:,1]),:][0],2))
np.savetxt('worker_bi_25_sol.txt', out_bi_25[np.argmin(out_bi_25[:,1]),:][0])
# Out:
# [0.   0.16 0.04 1.   0.81 0.84 0.74 1.  ]

# %%
sol_bi_25 = np.loadtxt('worker_bi_25_sol.txt')
y0_new=y0_use.copy()
y0_new = y0_new.reshape(21,10)
y0_new[18] = np.zeros(10)
y0_new=y0_new.reshape(210)
p = sol_bi_25
y0_new=vaccinate_sus_y0(p,y0_new)
t = np.linspace(0,4*4*7,300)
sol=scipy.integrate.solve_ivp(lambda t,y:coronavirusEqs_with_vaccination_only(t,y, params),[0,4*4*7], y0_new, t_eval=t)
sol_plot=np.reshape(sol.y,(21,10,300))
deaths = sol_plot[18,:,-1]-deaths_from_curr_inf 
print(np.round(sum(deaths)))
print(deaths)
np.savetxt('min_id_both_deaths_25.txt', deaths)
plotting_fun2(deaths,total_pops)
# Out:
# 57.0
# [2.25000266e-01 1.96760143e+00 7.24967496e+00 4.00550967e+01
#  1.62792176e-07 3.88922044e-01 7.40723056e-01 1.50732044e+00
#  4.90501081e+00 3.25274652e-08]
# array([3.65480201, 1.07871179, 1.00020826, 0.99900013, 2.32015885,
#        1.01843899])

# %% [markdown]
# # Working with YLLs

# %%
from YLL_funs import *

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(sp_ylls_25,[d for d in ref_dirs_10k_25p])
out = np.array(output)
idx = out.argsort()[:20]
starting_points_ylls_25 = ref_dirs_10k_25p[idx]
sp_1 = np.array([0,0,0,0.9,1,1,1,1])
sp_2 = np.array([0,0,1,1,0,0.3,1,1])
sp_3 = np.array([0, 0, 0.8, 1, 0, 1, 1, 1])
sp_4 = np.array([0, 0.2, 1, 1, 0, 0, 0, 0])
starting_points_ylls_25 = np.append(starting_points_ylls_25,sp_1).reshape(21,8)
starting_points_ylls_25 = np.append(starting_points_ylls_25,sp_2).reshape(22,8)
starting_points_ylls_25 = np.append(starting_points_ylls_25,sp_3).reshape(23,8)
starting_points_ylls_25 = np.append(starting_points_ylls_25,sp_4).reshape(24,8)
np.savetxt('starting_points_ylls_25p.txt', starting_points_ylls_25)

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(sp_ineq_ylls_25,[d for d in ref_dirs_10k_25p])
out = np.array(output)
idx = out.argsort()[:20]
starting_points_iy_25 = ref_dirs_10k_25p[idx]
sp_1 = np.array([0,0,0,0.9,1,1,1,1])
sp_2 = np.array([0,0,1,1,0,0.3,1,1])
sp_3 = np.array([0, 0, 0.8, 1, 0, 1, 1, 1])
sp_4 = np.array([0, 0.2, 1, 1, 0, 0, 0, 0])
starting_points_iy_25 = np.append(starting_points_iy_25,sp_1).reshape(21,8)
starting_points_iy_25 = np.append(starting_points_iy_25,sp_2).reshape(22,8)
starting_points_iy_25 = np.append(starting_points_iy_25,sp_3).reshape(23,8)
starting_points_iy_25 = np.append(starting_points_iy_25,sp_4).reshape(24,8)
np.savetxt('starting_points_ineq_ylls_25p.txt', starting_points_iy_25)

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(sp_ineq_idis_25,[d for d in ref_dirs_10k_25p])
out = np.array(output)
idx = out.argsort()[:20]
starting_points_idis_25 = ref_dirs_10k_25p[idx]
sp_1 = np.array([0,0,0,0.9,1,1,1,1])
sp_2 = np.array([0,0,1,1,0,0.3,1,1])
sp_3 = np.array([0, 0, 0.8, 1, 0, 1, 1, 1])
sp_4 = np.array([0, 0.2, 1, 1, 0, 0, 0, 0])
starting_points_idis_25 = np.append(starting_points_idis_25,sp_1).reshape(21,8)
starting_points_idis_25 = np.append(starting_points_idis_25,sp_2).reshape(22,8)
starting_points_idis_25 = np.append(starting_points_idis_25,sp_3).reshape(23,8)
starting_points_idis_25 = np.append(starting_points_idis_25,sp_4).reshape(24,8)
np.savetxt('starting_points_ineq_yll_idis_25p.txt', starting_points_idis_25)

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(sp_both_ylls_25,[d for d in ref_dirs_10k_25p])
out = np.array(output)
idx = out.argsort()[:20]
starting_points_by_25 = ref_dirs_10k_25p[idx]
sp_1 = np.array([0,0,0,0.9,1,1,1,1])
sp_2 = np.array([0,0,1,1,0,0.3,1,1])
sp_3 = np.array([0, 0, 0.8, 1, 0, 1, 1, 1])
sp_4 = np.array([0, 0.2, 1, 1, 0, 0, 0, 0])
starting_points_by_25 = np.append(starting_points_by_25,sp_1).reshape(21,8)
starting_points_by_25 = np.append(starting_points_by_25,sp_2).reshape(22,8)
starting_points_by_25 = np.append(starting_points_by_25,sp_3).reshape(23,8)
starting_points_by_25 = np.append(starting_points_by_25,sp_4).reshape(24,8)
np.savetxt('starting_points_both_ylls_25p.txt', starting_points_by_25)

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(sp_both_idis_25,[d for d in ref_dirs_10k_25p])
out = np.array(output)
idx = out.argsort()[:20]
starting_points_byi_25 = ref_dirs_10k_25p[idx]
sp_1 = np.array([0,0,0,0.9,1,1,1,1])
sp_2 = np.array([0,0,1,1,0,0.3,1,1])
sp_3 = np.array([0, 0, 0.8, 1, 0, 1, 1, 1])
sp_4 = np.array([0, 0.2, 1, 1, 0, 0, 0, 0])
starting_points_byi_25 = np.append(starting_points_byi_25,sp_1).reshape(21,8)
starting_points_byi_25 = np.append(starting_points_byi_25,sp_2).reshape(22,8)
starting_points_byi_25 = np.append(starting_points_byi_25,sp_3).reshape(23,8)
starting_points_byi_25 = np.append(starting_points_byi_25,sp_4).reshape(24,8)
np.savetxt('starting_points_both_ylls_idis_25p.txt', starting_points_byi_25)

# %%
starting_points_ylls_25  = np.loadtxt('starting_points_ylls_25p.txt')
starting_points_ineq_ylls_25 =np.loadtxt('starting_points_ineq_ylls_25p.txt')
starting_points_ineq_ylls_idis_25  = np.loadtxt('starting_points_ineq_yll_idis_25p.txt')
starting_points_by_25 = np.loadtxt('starting_points_both_ylls_25p.txt')
starting_points_byi_25 = np.loadtxt('starting_points_both_ylls_idis_25p.txt')

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(worker_ylls_25,[d for d in starting_points_ylls_25])
out_yll_25 = np.array(output)

print(np.round(out_yll_25[np.argmin(out_yll_25[:,1]),:][0],2))
np.savetxt('yll_25_sol.txt', out_yll_25[np.argmin(out_yll_25[:,1]),:][0])

sol_yll_25 = np.loadtxt('yll_25_sol.txt')

y0_new=y0_use.copy()
y0_new = y0_new.reshape(21,10)
y0_new[18] = np.zeros(10)
y0_new=y0_new.reshape(210)
p = sol_yll_25
y0_new=vaccinate_sus_y0(p,y0_new)
t = np.linspace(0,4*4*7,300)
sol=scipy.integrate.solve_ivp(lambda t,y:coronavirusEqs_with_vaccination_only(t,y, params),[0,4*4*7], y0_new, t_eval=t)
sol_plot=np.reshape(sol.y,(21,10,300))
deaths = sol_plot[18,:,-1]-deaths_from_curr_inf 
print(np.round(sum(deaths)))
print(np.round(deaths))
    
sum(abs(plotting_fun2(deaths,total_pops)-1))
# Out:
# [0.   0.   1.   0.88 0.   1.   1.   1.  ]
# 30.0
# [ 0.  2.  8.  0. 15.  0.  4.  0.  0.  0.]
# 11.379614978523541

# %%
sol_yll_25 = np.loadtxt('yll_25_sol.txt')
y0_new=y0_use.copy()
y0_new = y0_new.reshape(21,10)
y0_new[18] = np.zeros(10)
y0_new=y0_new.reshape(210)
p = sol_yll_25
y0_new=vaccinate_sus_y0(p,y0_new)
t = np.linspace(0,4*4*7,300)
sol=scipy.integrate.solve_ivp(lambda t,y:coronavirusEqs_with_vaccination_only(t,y, params),[0,4*4*7], y0_new, t_eval=t)
sol_plot=np.reshape(sol.y,(21,10,300))
deaths = sol_plot[18,:,-1]-deaths_from_curr_inf 
deaths
np.savetxt('min_ylls_25.txt', deaths)
#dalys = deaths*two_pop_daly
#dalys_per_100000 = (dalys/total_pops)*100000
#print(np.round(dalys_per_100000,1))
#print(sum(dalys_per_100000))
#print(1-sum(dalys_per_100000)/806.8319494141942)

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(worker_ineq_ylls_25,[d for d in starting_points_ineq_ylls_25 ])
out_iy_25 = np.array(output)

print(np.round(out_iy_25[np.argmin(out_iy_25[:,1]),:][0],2))
np.savetxt('ineq_yll_25_sol.txt', out_iy_25[np.argmin(out_iy_25[:,1]),:][0])

sol_iy_25 = np.loadtxt('ineq_yll_25_sol.txt')

y0_new=y0_use.copy()
y0_new = y0_new.reshape(21,10)
y0_new[18] = np.zeros(10)
y0_new=y0_new.reshape(210)
p = sol_iy_25
y0_new=vaccinate_sus_y0(p,y0_new)
t = np.linspace(0,4*4*7,300)
sol=scipy.integrate.solve_ivp(lambda t,y:coronavirusEqs_with_vaccination_only(t,y, params),[0,4*4*7], y0_new, t_eval=t)
sol_plot=np.reshape(sol.y,(21,10,300))
deaths = sol_plot[18,:,-1]-deaths_from_curr_inf 
print(np.round(sum(deaths)))
print(np.round(deaths))
    
sum(abs(plotting_fun2(deaths,total_pops)-1))
# Out:
# [0.   0.81 0.   0.   0.83 0.97 0.73 0.54]
# 228.0
# [  0.   2.   1.  41. 163.   0.   1.   0.   5.  14.]
# 2.8045467930505916

# %%
sol_iy_25 = np.loadtxt('ineq_yll_25_sol.txt')
y0_new=y0_use.copy()
y0_new = y0_new.reshape(21,10)
y0_new[18] = np.zeros(10)
y0_new=y0_new.reshape(210)
p = sol_iy_25
y0_new=vaccinate_sus_y0(p,y0_new)
t = np.linspace(0,4*4*7,300)
sol=scipy.integrate.solve_ivp(lambda t,y:coronavirusEqs_with_vaccination_only(t,y, params),[0,4*4*7], y0_new, t_eval=t)
sol_plot=np.reshape(sol.y,(21,10,300))
deaths = sol_plot[18,:,-1]-deaths_from_curr_inf
np.savetxt('min_abs_ineq_ylls_25.txt', deaths)
deaths
#dalys = deaths*two_pop_daly
#dalys_per_100000 = (dalys/total_pops)*100000
#print(np.round(dalys_per_100000,1))
#print(sum(dalys_per_100000))
#print(1-sum(dalys_per_100000)/806.8319494141942)
# Out:
# array([  0.21368969,   1.79489846,   1.40881617,  41.29165546,
#        163.4823291 ,   0.3705252 ,   0.61050945,   0.28829449,
#          4.94255852,  13.505438  ])

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(worker_ineq_ylls_idis_25,[d for d in starting_points_ineq_ylls_idis_25])
out_iyi_25 = np.array(output)

print(np.round(out_iyi_25[np.argmin(out_iyi_25[:,1]),:][0],2))
np.savetxt('ineq_yll_idis_25_sol.txt', out_iyi_25[np.argmin(out_iyi_25[:,1]),:][0])

sol_iyi_25 = np.loadtxt('ineq_yll_idis_25_sol.txt')

y0_new=y0_use.copy()
y0_new = y0_new.reshape(21,10)
y0_new[18] = np.zeros(10)
y0_new=y0_new.reshape(210)
p = sol_iyi_25
y0_new=vaccinate_sus_y0(p,y0_new)
t = np.linspace(0,4*4*7,300)
sol=scipy.integrate.solve_ivp(lambda t,y:coronavirusEqs_with_vaccination_only(t,y, params),[0,4*4*7], y0_new, t_eval=t)
sol_plot=np.reshape(sol.y,(21,10,300))
deaths = sol_plot[18,:,-1]-deaths_from_curr_inf 
print(np.round(sum(deaths)))
print(np.round(deaths))
np.savetxt('min_aid_ineq_ylls_25.txt', deaths)
sum(abs(plotting_fun2(deaths,total_pops)-1))
# Out:
# [0.15 0.35 0.32 0.3  0.29 0.53 0.57 0.6 ]
# 176.0
# [  0.   2.   6.  29. 110.   0.   3.   5.   9.  12.]
# 12.656526996645965

# %%
sol_iyi_25 = np.loadtxt('ineq_yll_idis_25_sol.txt')

y0_new=y0_use.copy()
y0_new = y0_new.reshape(21,10)
y0_new[18] = np.zeros(10)
y0_new=y0_new.reshape(210)
p = sol_iyi_25
y0_new=vaccinate_sus_y0(p,y0_new)
t = np.linspace(0,4*4*7,300)
sol=scipy.integrate.solve_ivp(lambda t,y:coronavirusEqs_with_vaccination_only(t,y, params),[0,4*4*7], y0_new, t_eval=t)
sol_plot=np.reshape(sol.y,(21,10,300))
deaths = sol_plot[18,:,-1]-deaths_from_curr_inf 
print(np.round(sum(deaths)))
print(np.round(deaths))
np.savetxt('min_id_ineq_ylls_25.txt', deaths)
sum(abs(plotting_fun2(deaths,total_pops)-1))
# Out:
# 176.0
# [  0.   2.   6.  29. 110.   0.   3.   5.   9.  12.]
# 12.656526996645965

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(worker_both_25,[d for d in starting_points_by_25])
out_by_25 = np.array(output)

print(np.round(out_by_25[np.argmin(out_by_25[:,1]),:][0],2))
np.savetxt('both_yll_25_sol.txt', out_by_25[np.argmin(out_by_25[:,1]),:][0])

sol_by_25 = np.loadtxt('both_yll_25_sol.txt')

y0_new=y0_use.copy()
y0_new = y0_new.reshape(21,10)
y0_new[18] = np.zeros(10)
y0_new=y0_new.reshape(210)
p = sol_by_25
y0_new=vaccinate_sus_y0(p,y0_new)
t = np.linspace(0,4*4*7,300)
sol=scipy.integrate.solve_ivp(lambda t,y:coronavirusEqs_with_vaccination_only(t,y, params),[0,4*4*7], y0_new, t_eval=t)
sol_plot=np.reshape(sol.y,(21,10,300))
deaths = sol_plot[18,:,-1]-deaths_from_curr_inf 
print(np.round(sum(deaths)))
print(np.round(deaths))
    
sum(abs(plotting_fun2(deaths,total_pops)-1))
# Out:
# [0.01 0.   0.64 0.52 0.83 0.81 0.9  0.78]
# 100.0
# [ 0.  2.  8. 14. 66.  0.  1.  2.  2.  5.]
# 2.779132487886746

# %%
y0_new=y0_use.copy()
y0_new = y0_new.reshape(21,10)
y0_new[18] = np.zeros(10)
y0_new=y0_new.reshape(210)
p = sol_by_25
y0_new=vaccinate_sus_y0(p,y0_new)
t = np.linspace(0,4*4*7,300)
sol=scipy.integrate.solve_ivp(lambda t,y:coronavirusEqs_with_vaccination_only(t,y, params),[0,4*4*7], y0_new, t_eval=t)
sol_plot=np.reshape(sol.y,(21,10,300))
deaths = sol_plot[18,:,-1]-deaths_from_curr_inf
np.savetxt('min_abs_both_ylls_25.txt', deaths)
deaths
#dalys = deaths*two_pop_daly
#dalys_per_100000 = (dalys/total_pops)*100000
#print(np.round(dalys_per_100000,1))
#print(sum(dalys_per_100000))
#print(1-sum(dalys_per_100000)/806.8319494141942)
# Out:
# array([ 0.22254446,  1.93081331,  8.4437388 , 14.1985746 , 65.5660847 ,
#         0.38458621,  0.65599264,  1.72789253,  1.71061848,  5.41639569])

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(worker_both_idis_25,[d for d in starting_points_byi_25])
out_byi_25 = np.array(output)

print(np.round(out_byi_25[np.argmin(out_byi_25[:,1]),:][0],2))
np.savetxt('both_yll_idis_25_sol.txt', out_byi_25[np.argmin(out_byi_25[:,1]),:][0])

sol_byi_25 = np.loadtxt('both_yll_idis_25_sol.txt')

y0_new=y0_use.copy()
y0_new = y0_new.reshape(21,10)
y0_new[18] = np.zeros(10)
y0_new=y0_new.reshape(210)
p = sol_byi_25
y0_new=vaccinate_sus_y0(p,y0_new)
t = np.linspace(0,4*4*7,300)
sol=scipy.integrate.solve_ivp(lambda t,y:coronavirusEqs_with_vaccination_only(t,y, params),[0,4*4*7], y0_new, t_eval=t)
sol_plot=np.reshape(sol.y,(21,10,300))
deaths = sol_plot[18,:,-1]-deaths_from_curr_inf 
print(np.round(sum(deaths)))
print(np.round(deaths))
np.savetxt('min_id_both_ylls_25.txt', deaths)
sum(abs(plotting_fun2(deaths,total_pops)-1))
# Out:
# [0.01 0.33 0.49 0.35 0.83 0.88 0.87 0.71]
# 127.0
# [ 0.  2.  5. 19. 89.  0.  1.  1.  2.  7.]
# 2.796571625853982

# %%
sol_byi_25 = np.loadtxt('both_yll_idis_25_sol.txt')

y0_new=y0_use.copy()
y0_new = y0_new.reshape(21,10)
y0_new[18] = np.zeros(10)
y0_new=y0_new.reshape(210)
p = sol_byi_25
y0_new=vaccinate_sus_y0(p,y0_new)
t = np.linspace(0,4*4*7,300)
sol=scipy.integrate.solve_ivp(lambda t,y:coronavirusEqs_with_vaccination_only(t,y, params),[0,4*4*7], y0_new, t_eval=t)
sol_plot=np.reshape(sol.y,(21,10,300))
deaths = sol_plot[18,:,-1]-deaths_from_curr_inf 
print(np.round(sum(deaths)))
print(np.round(deaths))
np.savetxt('min_id_both_ylls_25.txt', deaths)
sum(abs(plotting_fun2(deaths,total_pops)-1))
# Out:
# 127.0
# [ 0.  2.  5. 19. 89.  0.  1.  1.  2.  7.]
# 2.796571625853982
