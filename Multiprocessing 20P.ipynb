# %%
import numpy as np
import scipy
import matplotlib.pylab as plt
from matplotlib.pyplot import figure
from scipy.integrate import odeint
from scipy.optimize import minimize
import pickle
from timeit import default_timer as timer
import sys, getopt
import time
import csv
import multiprocessing as mp
from multiprocessing import Pool
import os
import pandas as pd
from scipy.optimize import Bounds

# %% [markdown]
# ### Import parameters for simulations

# %%
from two_pop_params_current import *
from init_cond_current import *

# %% [markdown]
# ### Import model, objective functions to minimize, and functions to display results

# %%
from coronavirusEqs import *
from deaths_combo20 import *
from ineq_measures_alone import *
from plotting_fn import *

# %%
#ref_dirs_10k_20p = np.zeros((10000,8))
#for i in range(10000):
#    it = 0
#    test=np.random.rand(8)
#    while (test[0:4]@y0_use[1:5]+test[4:]@y0_use[6:10])>0.2*N:
#        test=np.random.rand(8)
#    ref_dirs_10k_20p[i,:]=test
#np.savetxt('ref_dirs_10k_20p.txt', ref_dirs_10k_20p)
ref_dirs_10k_20p=np.loadtxt('ref_dirs_10k_20p.txt')

# %%
def check_constraint(p,pops):
    return (p[0:4]@pops[1:5]+p[4:]@pops[6:10])<0.2*N

# %% [markdown]
# # 20 % Cost Constraint (deaths)

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(sp_death_20,[d for d in ref_dirs_10k_20p])
out = np.array(output)
idx = out.argsort()[:20]
starting_points_d20_01 = ref_dirs_10k_20p[idx]
sp_1 = np.array([0,0,0,0.5,1,1,1,1])
sp_2 = np.array([0,0,0.6,1,0,0,1,1])
sp_3 = np.array([0, 0, 0.4, 1, 0, 1, 1, 1])
sp_4 = np.array([0, 0, 0.8, 1, 0, 0, 0, 0])
starting_points_d20_01 = np.append(starting_points_d20_01,sp_1).reshape(21,8)
starting_points_d20_01 = np.append(starting_points_d20_01,sp_2).reshape(22,8)
starting_points_d20_01 = np.append(starting_points_d20_01,sp_3).reshape(23,8)
starting_points_d20_01 = np.append(starting_points_d20_01,sp_4).reshape(24,8)
np.savetxt('starting_points_20p_combo0_death.txt', starting_points_d20_01)

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(sp_ineq_bars_20,[d for d in ref_dirs_10k_20p])
out = np.array(output)
idx = out.argsort()[:20]
starting_points_d20_20 = ref_dirs_10k_20p[idx]
sp_1 = np.array([0,0,0,0.5,1,1,1,1])
sp_2 = np.array([0,0,0.6,1,0,0,1,1])
sp_3 = np.array([0, 0, 0.4, 1, 0, 1, 1, 1])
sp_4 = np.array([0, 0, 0.8, 1, 0, 0, 0, 0])
starting_points_d20_20 = np.append(starting_points_d20_20,sp_1).reshape(21,8)
starting_points_d20_20 = np.append(starting_points_d20_20,sp_2).reshape(22,8)
starting_points_d20_20 = np.append(starting_points_d20_20,sp_3).reshape(23,8)
starting_points_d20_20 = np.append(starting_points_d20_20,sp_4).reshape(24,8)
np.savetxt('starting_points_20p_combo0_ineq_bars.txt', starting_points_d20_20)

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(sp_ineq_mort_20,[d for d in ref_dirs_10k_20p])
out = np.array(output)
idx = out.argsort()[:20]
starting_points_d20_20 = ref_dirs_10k_20p[idx]
sp_1 = np.array([0,0,0,0.5,1,1,1,1])
sp_2 = np.array([0,0,0.6,1,0,0,1,1])
sp_3 = np.array([0, 0, 0.4, 1, 0, 1, 1, 1])
sp_4 = np.array([0, 0, 0.8, 1, 0, 0, 0, 0])
starting_points_d20_20 = np.append(starting_points_d20_20,sp_1).reshape(21,8)
starting_points_d20_20 = np.append(starting_points_d20_20,sp_2).reshape(22,8)
starting_points_d20_20 = np.append(starting_points_d20_20,sp_3).reshape(23,8)
starting_points_d20_20 = np.append(starting_points_d20_20,sp_4).reshape(24,8)
np.savetxt('starting_points_20p_combo0_ineq_mort.txt', starting_points_d20_20)

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(sp_ineq_mort_IDIS_20,[d for d in ref_dirs_10k_20p])
out = np.array(output)
idx = out.argsort()[:20]
starting_points_ineq_mi_20 = ref_dirs_10k_20p[idx]
sp_1 = np.array([0,0,0,0.5,1,1,1,1])
sp_2 = np.array([0,0,0.6,1,0,0,1,1])
sp_3 = np.array([0, 0, 0.4, 1, 0, 1, 1, 1])
sp_4 = np.array([0, 0, 0.8, 1, 0, 0, 0, 0])
starting_points_ineq_mi_20 = np.append(starting_points_ineq_mi_20,sp_1).reshape(21,8)
starting_points_ineq_mi_20 = np.append(starting_points_ineq_mi_20,sp_2).reshape(22,8)
starting_points_ineq_mi_20 = np.append(starting_points_ineq_mi_20,sp_3).reshape(23,8)
starting_points_ineq_mi_20 = np.append(starting_points_ineq_mi_20,sp_4).reshape(24,8)
np.savetxt('starting_points_20p_combo0_ineq_mi.txt', starting_points_ineq_mi_20)

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(sp_both_bars_20,[d for d in ref_dirs_10k_20p])
out = np.array(output)
idx = out.argsort()[:20]
starting_points_bb_20 = ref_dirs_10k_20p[idx]
sp_1 = np.array([0,0,0,0.5,1,1,1,1])
sp_2 = np.array([0,0,0.6,1,0,0,1,1])
sp_3 = np.array([0, 0, 0.4, 1, 0, 1, 1, 1])
sp_4 = np.array([0, 0, 0.8, 1, 0, 0, 0, 0])
starting_points_bb_20 = np.append(starting_points_bb_20,sp_2).reshape(21,8)
starting_points_bb_20 = np.append(starting_points_bb_20,sp_3).reshape(22,8)
starting_points_bb_20 = np.append(starting_points_bb_20,sp_4).reshape(23,8)
starting_points_bb_20 = np.append(starting_points_bb_20,sp_1).reshape(24,8)
np.savetxt('starting_points_20p_combo0_bb.txt', starting_points_bb_20)

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(sp_both_mort_20,[d for d in ref_dirs_10k_20p])
out = np.array(output)
idx = out.argsort()[:20]
starting_points_bm_20 = ref_dirs_10k_20p[idx]
sp_1 = np.array([0,0,0,0.5,1,1,1,1])
sp_2 = np.array([0,0,0.6,1,0,0,1,1])
sp_3 = np.array([0.2, 0, 0, 0, 1, 1, 0, 0])
sp_4 = np.array([0.  , 0, 0.7 , 1 , 0.  , 0.  , 0.6, 1.])
starting_points_bm_20 = np.append(starting_points_bm_20,sp_2).reshape(21,8)
starting_points_bm_20 = np.append(starting_points_bm_20,sp_3).reshape(22,8)
starting_points_bm_20 = np.append(starting_points_bm_20,sp_4).reshape(23,8)
starting_points_bm_20 = np.append(starting_points_bm_20,sp_1).reshape(24,8)
np.savetxt('starting_points_20p_combo0_bm.txt', starting_points_bm_20)

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(sp_both_mort_IDIS_20,[d for d in ref_dirs_10k_20p])
out = np.array(output)
idx = out.argsort()[:20]
starting_points_bi_20 = ref_dirs_10k_20p[idx]
sp_1 = np.array([0,0,0,0.5,1,1,1,1])
sp_2 = np.array([0,0,0.6,1,0,0,1,1])
sp_3 = np.array([0, 0, 0.4, 1, 0, 1, 1, 1])
sp_4 = np.array([0, 0, 0.8, 1, 0, 0, 0, 0])
starting_points_bi_20 = np.append(starting_points_bi_20,sp_2).reshape(21,8)
starting_points_bi_20 = np.append(starting_points_bi_20,sp_3).reshape(22,8)
starting_points_bi_20 = np.append(starting_points_bi_20,sp_4).reshape(23,8)
starting_points_bi_20 = np.append(starting_points_bi_20,sp_1).reshape(24,8)
np.savetxt('starting_points_20p_combo0_bi.txt', starting_points_bi_20)

# %%
starting_points_deaths_20  = np.loadtxt('starting_points_20p_combo0_death.txt')
starting_points_ineq_bars_20 =np.loadtxt('starting_points_20p_combo0_ineq_bars.txt')
starting_points_ineq_mort_20  = np.loadtxt('starting_points_20p_combo0_ineq_mort.txt')
starting_points_ineq_mi_20 = np.loadtxt('starting_points_20p_combo0_ineq_mi.txt')
starting_points_bb_20 = np.loadtxt('starting_points_20p_combo0_bb.txt')
starting_points_bm_20 = np.loadtxt('starting_points_20p_combo0_bm.txt')
starting_points_bi_20=np.loadtxt('starting_points_20p_combo0_bi.txt')

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(worker_death_20,[d for d in starting_points_deaths_20])
out01 = np.array(output)

print(np.round(out01[np.argmin(out01[:,1]),:][0],2))
#np.savetxt('worker_death_20_sol.txt', out01[np.argmin(out01[:,1]),:][0])
# Out:
# [0.   0.   0.42 1.   0.   1.   1.   1.  ]

# %%
sol_d20 = np.loadtxt('worker_death_20_sol.txt')

y0_new=y0_use.copy()
y0_new = y0_new.reshape(21,10)
y0_new[18] = np.zeros(10)
y0_new=y0_new.reshape(210)
p = sol_d20
y0_new=vaccinate_sus_y0(p,y0_new)
t = np.linspace(0,4*4*7,300)
sol=scipy.integrate.solve_ivp(lambda t,y:coronavirusEqs_with_vaccination_only(t,y, params),[0,4*4*7], y0_new, t_eval=t)
sol_plot=np.reshape(sol.y,(21,10,300))
deaths = sol_plot[18,:,-1]-deaths_from_curr_inf 
print(np.round(sum(deaths)))
print(deaths)
np.savetxt('min_deaths_20.txt', deaths)    
sum(abs(plotting_fun2(deaths,total_pops)-1))
# Out:
# 41.0
# [2.41268495e-01 2.18795433e+00 9.31967291e+00 2.44007190e+01
#  3.67758467e-07 4.25683580e-01 4.62195495e+00 2.61043409e-09
#  7.67125208e-09 3.92183264e-08]
# 10.564459770941976

# %%
starting_points_ineq_bars_20 = np.append(starting_points_ineq_bars_20,np.array([0.02, 0.52, 0.47, 0.3,  0.17, 0.31, 0.28, 0.35])).reshape(25,8)

if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(worker_ineq_bars_20,[d for d in starting_points_ineq_bars_20])
out_ineq_bars_20 = np.array(output)

print(np.round(out_ineq_bars_20[np.argmin(out_ineq_bars_20[:,1]),:][0],2))
np.savetxt('worker_ineq_bars_20_sol.txt', out_ineq_bars_20[np.argmin(out_ineq_bars_20[:,1]),:][0])
# Out:
# [0.02 0.36 0.02 0.24 0.83 0.88 0.73 0.63]

# %%
sol_ineq_bars_20=np.loadtxt('worker_ineq_bars_20_sol.txt')

y0_new=y0_use.copy()
y0_new = y0_new.reshape(21,10)
y0_new[18] = np.zeros(10)
y0_new=y0_new.reshape(210)
p = sol_ineq_bars_20
y0_new=vaccinate_sus_y0(p,y0_new)
t = np.linspace(0,4*4*7,300)
sol=scipy.integrate.solve_ivp(lambda t,y:coronavirusEqs_with_vaccination_only(t,y, params),[0,4*4*7], y0_new, t_eval=t)
sol_plot=np.reshape(sol.y,(21,10,300))
deaths = sol_plot[18,:,-1]-deaths_from_curr_inf 
print(np.round(sum(deaths)))
print(deaths)
np.savetxt('min_rel_ineq_deaths_20.txt', deaths)  
sum(abs(plotting_fun2(deaths,total_pops)-1))
# Out:
# 196.0
# [  0.22766866   1.95278597   5.4359044   43.74067933 126.10434296
#    0.39368372   0.68184281   1.12771886   5.35978868  10.86214864]
# 2.66378142338415

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(worker_ineq_mort_20,[d for d in starting_points_ineq_mort_20])
out_ineq_mort_20 = np.array(output)

print(np.round(out_ineq_mort_20[np.argmin(out_ineq_mort_20[:,1]),:][0],2))
np.savetxt('worker_ineq_mort_20_sol.txt', out_ineq_mort_20[np.argmin(out_ineq_mort_20[:,1]),:][0])
# Out:
# [0.1  0.05 0.06 0.2  0.86 0.82 0.74 0.61]

# %%
sol_ineq_mort_20=np.loadtxt('worker_ineq_mort_20_sol.txt')

y0_new=y0_use.copy()
y0_new = y0_new.reshape(21,10)
y0_new[18] = np.zeros(10)
y0_new=y0_new.reshape(210)
p = sol_ineq_mort_20
y0_new=vaccinate_sus_y0(p,y0_new)
t = np.linspace(0,4*4*7,300)
sol=scipy.integrate.solve_ivp(lambda t,y:coronavirusEqs_with_vaccination_only(t,y, params),[0,4*4*7], y0_new, t_eval=t)
sol_plot=np.reshape(sol.y,(21,10,300))
deaths = sol_plot[18,:,-1]-deaths_from_curr_inf
print(np.round(sum(deaths)))
print(deaths)
np.savetxt('min_abs_ineq_deaths_20.txt', deaths)  
plotting_fun2(deaths,total_pops)
# Out:
# 220.0
# [  0.23774662   1.90749985   9.04690837  45.12982863 142.96027857
#    0.41040134   0.59174946   1.88085044   5.53169285  12.31165257]
# array([3.64988129, 0.88891463, 1.00013231, 0.99994873, 1.00000459,
#        1.00291957])

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(worker_ineq_mort_IDIS_20,[d for d in starting_points_ineq_mi_20])
out_ineq_mi_20 = np.array(output)

print(np.round(out_ineq_mi_20[np.argmin(out_ineq_mi_20[:,1]),:][0],2))
np.savetxt('worker_ineq_mi_20_sol.txt', out_ineq_mi_20[np.argmin(out_ineq_mi_20[:,1]),:][0])
# Out:
# [0.02 0.26 0.31 0.07 0.83 0.86 0.81 0.55]

# %%
sol_ineq_mi_20=np.loadtxt('worker_ineq_mi_20_sol.txt')

y0_new=y0_use.copy()
y0_new = y0_new.reshape(21,10)
y0_new[18] = np.zeros(10)
y0_new=y0_new.reshape(210)
p = sol_ineq_mi_20
y0_new=vaccinate_sus_y0(p,y0_new)
t = np.linspace(0,4*4*7,300)
sol=scipy.integrate.solve_ivp(lambda t,y:coronavirusEqs_with_vaccination_only(t,y, params),[0,4*4*7], y0_new, t_eval=t)
sol_plot=np.reshape(sol.y,(21,10,300))
deaths = sol_plot[18,:,-1]-deaths_from_curr_inf 
print(np.round(sum(deaths)))
print(deaths)
np.savetxt('min_id_ineq_deaths_20.txt', deaths)  
plotting_fun2(np.round(deaths,2),total_pops)
# Out:
# 213.0
# [  0.22738772   1.95080105   6.35060388  29.93730993 155.27488059
#    0.39318645   0.68413042   1.32163254   3.67360849  13.36865871]
# array([3.58526364, 0.99921971, 1.00000827, 0.99999454, 0.9998731 ,
#        1.00400326])

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(worker_both_bars_20,[d for d in starting_points_bb_20])
out_bb_20 = np.array(output)

print(np.round(out_bb_20[np.argmin(out_bb_20[:,1]),:][0],2))
np.savetxt('worker_bb_20_sol.txt', out_bb_20[np.argmin(out_bb_20[:,1]),:][0])
# Out:
# [0.   0.03 0.06 1.   0.43 0.82 0.75 1.  ]

# %%
sol_bb_20=np.loadtxt('worker_bb_20_sol.txt')
y0_new=y0_use.copy()
y0_new = y0_new.reshape(21,10)
y0_new[18] = np.zeros(10)
y0_new=y0_new.reshape(210)
p = sol_bb_20
y0_new=vaccinate_sus_y0(p,y0_new)
t = np.linspace(0,4*4*7,300)
sol=scipy.integrate.solve_ivp(lambda t,y:coronavirusEqs_with_vaccination_only(t,y, params),[0,4*4*7], y0_new, t_eval=t)
sol_plot=np.reshape(sol.y,(21,10,300))
deaths = sol_plot[18,:,-1]-deaths_from_curr_inf 
print(np.round(sum(deaths)))
print(deaths)
np.savetxt('min_rel_both_deaths_20.txt', deaths)  
plotting_fun2(deaths,total_pops)
# Out:
# 65.0
# [2.42832395e-01 2.19756273e+00 9.37380745e+00 4.32050132e+01
#  1.61723300e-07 4.23577701e-01 2.57446971e+00 1.94693913e+00
#  5.30471438e+00 3.23513003e-08]
# array([3.68816882, 3.35685975, 0.99917079, 1.00163899, 2.32284471,
#        1.12698431])

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(worker_both_mort_20,[d for d in starting_points_bm_20])
out_bm_20 = np.array(output)

print(np.round(out_bm_20[np.argmin(out_bm_20[:,1]),:][0],2))
np.savetxt('worker_bm_20_sol.txt', out_bm_20[np.argmin(out_bm_20[:,1]),:][0])
# Out:
# [0.   0.   0.47 1.   0.   0.82 0.87 1.  ]

# %%
sol_bm_20 = np.loadtxt('worker_bm_20_sol.txt')

y0_new=y0_use.copy()
y0_new = y0_new.reshape(21,10)
y0_new[18] = np.zeros(10)
y0_new=y0_new.reshape(210)
p = sol_bm_20
y0_new=vaccinate_sus_y0(p,y0_new)
t = np.linspace(0,4*4*7,300)
sol=scipy.integrate.solve_ivp(lambda t,y:coronavirusEqs_with_vaccination_only(t,y, params),[0,4*4*7], y0_new, t_eval=t)
sol_plot=np.reshape(sol.y,(21,10,300))
deaths = sol_plot[18,:,-1]-deaths_from_curr_inf 
print(np.round(sum(deaths)))
print(deaths)
np.savetxt('min_abs_both_deaths_20.txt', deaths)  
plotting_fun2(deaths,total_pops)
# Out:
# 45.0
# [2.44406846e-01 2.22853960e+00 9.51924360e+00 2.26095736e+01
#  1.99836471e-07 4.32239021e-01 4.73869717e+00 1.97854968e+00
#  2.77064927e+00 3.72599231e-08]
# array([3.73933979, 6.09291742, 0.99988005, 0.99970656, 2.1650515 ,
#        1.40471911])

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(worker_both_mort_IDIS_20,[d for d in starting_points_bi_20])
out_bi_20 = np.array(output)

print(np.round(out_bi_20[np.argmin(out_bi_20[:,1]),:][0],2))
np.savetxt('worker_bi_20_sol.txt', out_bi_20[np.argmin(out_bi_20[:,1]),:][0])
# Out:
# [0.   0.04 0.   1.   0.49 0.82 0.73 1.  ]

# %%
sol_bi_20 = np.loadtxt('worker_bi_20_sol.txt')
y0_new=y0_use.copy()
y0_new = y0_new.reshape(21,10)
y0_new[18] = np.zeros(10)
y0_new=y0_new.reshape(210)
p = sol_bi_20
y0_new=vaccinate_sus_y0(p,y0_new)
t = np.linspace(0,4*4*7,300)
sol=scipy.integrate.solve_ivp(lambda t,y:coronavirusEqs_with_vaccination_only(t,y, params),[0,4*4*7], y0_new, t_eval=t)
sol_plot=np.reshape(sol.y,(21,10,300))
deaths = sol_plot[18,:,-1]-deaths_from_curr_inf 
print(np.round(sum(deaths)))
print(deaths)
np.savetxt('min_id_both_deaths_20.txt', deaths)      
plotting_fun2(deaths,total_pops)
# Out:
# 68.0
# [2.42463407e-01 2.19711521e+00 9.21815783e+00 4.63957491e+01
#  1.61782459e-07 4.22157220e-01 2.28780866e+00 1.91500253e+00
#  5.68503353e+00 3.23633120e-08]
# array([3.68139436, 2.98368907, 0.99937527, 0.99962751, 2.32285744,
#        1.10235759])

# %% [markdown]
# # Working with YLLs

# %%
from YLL_funs import *

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(sp_ylls_20,[d for d in ref_dirs_10k_20p])
out = np.array(output)
idx = out.argsort()[:20]
starting_points_ylls_20 = ref_dirs_10k_20p[idx]
sp_1 = np.array([0,0,0,0.5,1,1,1,1])
sp_2 = np.array([0,0,0.6,1,0,0,1,1])
sp_3 = np.array([0.2, 0, 0, 0, 1, 1, 0, 0])
sp_4 = np.array([0.  , 0, 0.7 , 1 , 0.  , 0.  , 0.6, 1.])
starting_points_ylls_20 = np.append(starting_points_ylls_20,sp_1).reshape(21,8)
starting_points_ylls_20 = np.append(starting_points_ylls_20,sp_2).reshape(22,8)
starting_points_ylls_20 = np.append(starting_points_ylls_20,sp_3).reshape(23,8)
starting_points_ylls_20 = np.append(starting_points_ylls_20,sp_4).reshape(24,8)
#np.savetxt('starting_points_ylls_20p.txt', starting_points_ylls_20)

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(sp_ineq_ylls_20,[d for d in ref_dirs_10k_20p])
out = np.array(output)
idx = out.argsort()[:20]
starting_points_iy_20 = ref_dirs_10k_20p[idx]
sp_1 = np.array([0,0,0,0.5,1,1,1,1])
sp_2 = np.array([0,0,0.6,1,0,0,1,1])
sp_3 = np.array([0.2, 0, 0, 0, 1, 1, 0, 0])
sp_4 = np.array([0.  , 0, 0.7 , 1 , 0.  , 0.  , 0.6, 1.])
starting_points_iy_20 = np.append(starting_points_iy_20,sp_1).reshape(21,8)
starting_points_iy_20 = np.append(starting_points_iy_20,sp_2).reshape(22,8)
starting_points_iy_20 = np.append(starting_points_iy_20,sp_3).reshape(23,8)
starting_points_iy_20 = np.append(starting_points_iy_20,sp_4).reshape(24,8)
np.savetxt('starting_points_ineq_ylls_20p.txt', starting_points_iy_20)

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(sp_ineq_idis_20,[d for d in ref_dirs_10k_20p])
out = np.array(output)
idx = out.argsort()[:20]
starting_points_idis_20 = ref_dirs_10k_20p[idx]
sp_1 = np.array([0,0,0,0.5,1,1,1,1])
sp_2 = np.array([0,0,0.6,1,0,0,1,1])
sp_3 = np.array([0.2, 0, 0, 0, 1, 1, 0, 0])
sp_4 = np.array([0.  , 0, 0.7 , 1 , 0.  , 0.  , 0.6, 1.])
starting_points_idis_20 = np.append(starting_points_idis_20,sp_1).reshape(21,8)
starting_points_idis_20 = np.append(starting_points_idis_20,sp_2).reshape(22,8)
starting_points_idis_20 = np.append(starting_points_idis_20,sp_3).reshape(23,8)
starting_points_idis_20 = np.append(starting_points_idis_20,sp_4).reshape(24,8)
np.savetxt('starting_points_ineq_yll_idis_20p.txt', starting_points_idis_20)

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(sp_both_ylls_20,[d for d in ref_dirs_10k_20p])
out = np.array(output)
idx = out.argsort()[:20]
starting_points_by_20 = ref_dirs_10k_20p[idx]
sp_1 = np.array([0,0,0,0.5,1,1,1,1])
sp_2 = np.array([0,0,0.6,1,0,0,1,1])
sp_3 = np.array([0.2, 0, 0, 0, 1, 1, 0, 0])
sp_4 = np.array([0.  , 0, 0.7 , 1 , 0.  , 0.  , 0.6, 1.])
starting_points_by_20 = np.append(starting_points_by_20,sp_1).reshape(21,8)
starting_points_by_20 = np.append(starting_points_by_20,sp_2).reshape(22,8)
starting_points_by_20 = np.append(starting_points_by_20,sp_3).reshape(23,8)
starting_points_by_20 = np.append(starting_points_by_20,sp_4).reshape(24,8)
np.savetxt('starting_points_both_ylls_20p.txt', starting_points_by_20)

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(sp_both_idis_20,[d for d in ref_dirs_10k_20p])
out = np.array(output)
idx = out.argsort()[:20]
starting_points_byi_20 = ref_dirs_10k_20p[idx]
sp_1 = np.array([0,0,0,0.5,1,1,1,1])
sp_2 = np.array([0,0,0.6,1,0,0,1,1])
sp_3 = np.array([0.2, 0, 0, 0, 1, 1, 0, 0])
sp_4 = np.array([0.  , 0, 0.7 , 1 , 0.  , 0.  , 0.6, 1.])
starting_points_byi_20 = np.append(starting_points_byi_20,sp_1).reshape(21,8)
starting_points_byi_20 = np.append(starting_points_byi_20,sp_2).reshape(22,8)
starting_points_byi_20 = np.append(starting_points_byi_20,sp_3).reshape(23,8)
starting_points_byi_20 = np.append(starting_points_byi_20,sp_4).reshape(24,8)
np.savetxt('starting_points_both_ylls_idis_20p.txt', starting_points_byi_20)

# %%
starting_points_ylls_20  = np.loadtxt('starting_points_ylls_20p.txt')
starting_points_ineq_ylls_20 =np.loadtxt('starting_points_ineq_ylls_20p.txt')
starting_points_ineq_ylls_idis_20  = np.loadtxt('starting_points_ineq_yll_idis_20p.txt')
starting_points_by_20 = np.loadtxt('starting_points_both_ylls_20p.txt')
starting_points_byi_20 = np.loadtxt('starting_points_both_ylls_idis_20p.txt')

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(worker_ylls_20,[d for d in starting_points_ylls_20])
out_yll_20 = np.array(output)

print(np.round(out_yll_20[np.argmin(out_yll_20[:,1]),:][0],2))
#np.savetxt('yll_20_sol.txt', out_yll_20[np.argmin(out_yll_20[:,1]),:][0])

sol_yll_20 = np.loadtxt('yll_20_sol.txt')

y0_new=y0_use.copy()
y0_new = y0_new.reshape(21,10)
y0_new[18] = np.zeros(10)
y0_new=y0_new.reshape(210)
p = sol_yll_20
y0_new=vaccinate_sus_y0(p,y0_new)
t = np.linspace(0,4*4*7,300)
sol=scipy.integrate.solve_ivp(lambda t,y:coronavirusEqs_with_vaccination_only(t,y, params),[0,4*4*7], y0_new, t_eval=t)
sol_plot=np.reshape(sol.y,(21,10,300))
deaths = sol_plot[18,:,-1]-deaths_from_curr_inf 
print(np.round(sum(deaths)))
print(np.round(deaths))
    
sum(abs(plotting_fun2(deaths,total_pops)-1))
# Out:
# [0.   0.   1.   0.42 0.   1.   1.   1.  ]
# 95.0
# [ 0.  2.  9.  0. 80.  0.  4.  0.  0.  0.]
# 11.629971455328196

# %%
sol_yll_20 = np.loadtxt('yll_20_sol.txt')
y0_new=y0_use.copy()
y0_new = y0_new.reshape(21,10)
y0_new[18] = np.zeros(10)
y0_new=y0_new.reshape(210)
p = sol_yll_20
y0_new=vaccinate_sus_y0(p,y0_new)
t = np.linspace(0,4*4*7,300)
sol=scipy.integrate.solve_ivp(lambda t,y:coronavirusEqs_with_vaccination_only(t,y, params),[0,4*4*7], y0_new, t_eval=t)
sol_plot=np.reshape(sol.y,(21,10,300))
deaths = sol_plot[18,:,-1]-deaths_from_curr_inf 
np.savetxt('min_ylls_20.txt', deaths)  
print(sum(deaths))
#dalys = deaths*two_pop_daly
#dalys_per_100000 = (dalys/total_pops)*100000
#print(np.round(dalys_per_100000,1))
#print(sum(dalys_per_100000))
#print(1-sum(dalys_per_100000)/806.8319494141942)
# Out:
# 95.4877436665665

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(worker_ineq_ylls_20,[d for d in starting_points_ineq_ylls_20 ])
out_iy_20 = np.array(output)

print(np.round(out_iy_20[np.argmin(out_iy_20[:,1]),:][0],2))
np.savetxt('ineq_yll_20_sol.txt', out_iy_20[np.argmin(out_iy_20[:,1]),:][0])

sol_iy_20 = np.loadtxt('ineq_yll_20_sol.txt')

y0_new=y0_use.copy()
y0_new = y0_new.reshape(21,10)
y0_new[18] = np.zeros(10)
y0_new=y0_new.reshape(210)
p = sol_iy_20
y0_new=vaccinate_sus_y0(p,y0_new)
t = np.linspace(0,4*4*7,300)
sol=scipy.integrate.solve_ivp(lambda t,y:coronavirusEqs_with_vaccination_only(t,y, params),[0,4*4*7], y0_new, t_eval=t)
sol_plot=np.reshape(sol.y,(21,10,300))
deaths = sol_plot[18,:,-1]-deaths_from_curr_inf 
print(np.round(sum(deaths)))
print(np.round(deaths))
    
sum(abs(plotting_fun2(deaths,total_pops)-1))
# Out:
# [0.   0.81 0.   0.   0.83 0.96 0.73 0.54]
# 228.0
# [  0.   2.   1.  41. 164.   0.   1.   0.   5.  14.]
# 2.807944827394085

# %%
sol_iy_20 = np.loadtxt('ineq_yll_20_sol.txt')
y0_new=y0_use.copy()
y0_new = y0_new.reshape(21,10)
y0_new[18] = np.zeros(10)
y0_new=y0_new.reshape(210)
p = sol_iy_20
y0_new=vaccinate_sus_y0(p,y0_new)
t = np.linspace(0,4*4*7,300)
sol=scipy.integrate.solve_ivp(lambda t,y:coronavirusEqs_with_vaccination_only(t,y, params),[0,4*4*7], y0_new, t_eval=t)
sol_plot=np.reshape(sol.y,(21,10,300))
deaths = sol_plot[18,:,-1]-deaths_from_curr_inf
np.savetxt('min_abs_ineq_ylls_20.txt', deaths) 
deaths
#dalys = deaths*two_pop_daly
#dalys_per_100000 = (dalys/total_pops)*100000
#print(np.round(dalys_per_100000,1))
#print(sum(dalys_per_100000))
#print(1-sum(dalys_per_100000)/806.8319494141942)
# Out:
# array([  0.21375194,   1.79368102,   1.43725702,  41.31670748,
#        163.56324434,   0.37062723,   0.60885067,   0.29369383,
#          4.94548384,  13.51202186])

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(worker_ineq_ylls_idis_20,[d for d in starting_points_ineq_ylls_idis_20])
out_iyi_20 = np.array(output)

print(np.round(out_iyi_20[np.argmin(out_iyi_20[:,1]),:][0],2))
np.savetxt('ineq_yll_idis_20_sol.txt', out_iyi_20[np.argmin(out_iyi_20[:,1]),:][0])

sol_iyi_20 = np.loadtxt('ineq_yll_idis_20_sol.txt')

y0_new=y0_use.copy()
y0_new = y0_new.reshape(21,10)
y0_new[18] = np.zeros(10)
y0_new=y0_new.reshape(210)
p = sol_iyi_20
y0_new=vaccinate_sus_y0(p,y0_new)
t = np.linspace(0,4*4*7,300)
sol=scipy.integrate.solve_ivp(lambda t,y:coronavirusEqs_with_vaccination_only(t,y, params),[0,4*4*7], y0_new, t_eval=t)
sol_plot=np.reshape(sol.y,(21,10,300))
deaths = sol_plot[18,:,-1]-deaths_from_curr_inf 
print(np.round(sum(deaths)))
print(np.round(deaths))
np.savetxt('min_id_ineq_ylls_20.txt', deaths)
sum(abs(plotting_fun2(deaths,total_pops)-1))
# Out:
# [0.11 0.24 0.24 0.22 0.4  0.59 0.35 0.41]
# 229.0
# [  0.   2.   7.  36. 140.   0.   3.   5.  15.  21.]
# 12.208474964645756

# %%
sol_iyi_20 = np.loadtxt('ineq_yll_idis_20_sol.txt')

y0_new=y0_use.copy()
y0_new = y0_new.reshape(21,10)
y0_new[18] = np.zeros(10)
y0_new=y0_new.reshape(210)
p = sol_iyi_20
y0_new=vaccinate_sus_y0(p,y0_new)
t = np.linspace(0,4*4*7,300)
sol=scipy.integrate.solve_ivp(lambda t,y:coronavirusEqs_with_vaccination_only(t,y, params),[0,4*4*7], y0_new, t_eval=t)
sol_plot=np.reshape(sol.y,(21,10,300))
deaths = sol_plot[18,:,-1]-deaths_from_curr_inf 
print(np.round(sum(deaths)))
print(np.round(deaths))
np.savetxt('min_id_ineq_ylls_20.txt', deaths)
sum(abs(plotting_fun2(deaths,total_pops)-1))
# Out:
# 229.0
# [  0.   2.   7.  36. 140.   0.   3.   5.  15.  21.]
# 12.208474964645756

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(worker_both_20,[d for d in starting_points_by_20])
out_by_20 = np.array(output)

print(np.round(out_by_20[np.argmin(out_by_20[:,1]),:][0],2))
np.savetxt('both_yll_20_sol.txt', out_by_20[np.argmin(out_by_20[:,1]),:][0])

sol_by_20 = np.loadtxt('both_yll_20_sol.txt')

y0_new=y0_use.copy()
y0_new = y0_new.reshape(21,10)
y0_new[18] = np.zeros(10)
y0_new=y0_new.reshape(210)
p = sol_by_20
y0_new=vaccinate_sus_y0(p,y0_new)
t = np.linspace(0,4*4*7,300)
sol=scipy.integrate.solve_ivp(lambda t,y:coronavirusEqs_with_vaccination_only(t,y, params),[0,4*4*7], y0_new, t_eval=t)
sol_plot=np.reshape(sol.y,(21,10,300))
deaths = sol_plot[18,:,-1]-deaths_from_curr_inf 
print(np.round(sum(deaths)))
print(np.round(deaths))
    
sum(abs(plotting_fun2(deaths,total_pops)-1))
# Out:
# [0.   0.   0.68 0.05 0.83 0.81 0.92 0.56]
# 194.0
# [  0.   2.   9.  13. 153.   0.   1.   2.   2.  13.]
# 2.788757083897621

# %%
sol_by_20 = np.loadtxt('both_yll_20_sol.txt')
y0_new=y0_use.copy()
y0_new = y0_new.reshape(21,10)
y0_new[18] = np.zeros(10)
y0_new=y0_new.reshape(210)
p = sol_by_20
y0_new=vaccinate_sus_y0(p,y0_new)
t = np.linspace(0,4*4*7,300)
sol=scipy.integrate.solve_ivp(lambda t,y:coronavirusEqs_with_vaccination_only(t,y, params),[0,4*4*7], y0_new, t_eval=t)
sol_plot=np.reshape(sol.y,(21,10,300))
deaths = sol_plot[18,:,-1]-deaths_from_curr_inf
np.savetxt('min_abs_both_ylls_20.txt', deaths)
deaths
#dalys = deaths*two_pop_daly
#dalys_per_100000 = (dalys/total_pops)*100000
#print(np.round(dalys_per_100000,1))
#print(sum(dalys_per_100000))
#print(1-sum(dalys_per_100000)/806.8319494141942)
# Out:
# array([  0.23122314,   2.04938711,   8.9358145 ,  13.42165878,
#        152.68025356,   0.39920968,   0.69708242,   1.82858796,
#          1.6065525 ,  12.61306196])

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
    output = p.map(worker_both_idis_20,[d for d in starting_points_byi_20])
out_byi_20 = np.array(output)

print(np.round(out_byi_20[np.argmin(out_byi_20[:,1]),:][0],2))
np.savetxt('both_yll_idis_20_sol.txt', out_byi_20[np.argmin(out_byi_20[:,1]),:][0])

sol_byi_20 = np.loadtxt('both_yll_idis_20_sol.txt')

y0_new=y0_use.copy()
y0_new = y0_new.reshape(21,10)
y0_new[18] = np.zeros(10)
y0_new=y0_new.reshape(210)
p = sol_byi_20
y0_new=vaccinate_sus_y0(p,y0_new)
t = np.linspace(0,4*4*7,300)
sol=scipy.integrate.solve_ivp(lambda t,y:coronavirusEqs_with_vaccination_only(t,y, params),[0,4*4*7], y0_new, t_eval=t)
sol_plot=np.reshape(sol.y,(21,10,300))
deaths = sol_plot[18,:,-1]-deaths_from_curr_inf 
print(np.round(sum(deaths)))
print(np.round(deaths))
np.savetxt('min_id_both_ylls_20.txt', deaths)
sum(abs(plotting_fun2(deaths,total_pops)-1))
# Out:
# [0.   0.   0.5  0.24 0.83 0.81 0.87 0.65]
# 170.0
# [  0.   2.   9.  22. 121.   0.   1.   2.   3.  10.]
# 2.7846528047717762

# %%
sol_byi_20 = np.loadtxt('both_yll_idis_20_sol.txt')

y0_new=y0_use.copy()
y0_new = y0_new.reshape(21,10)
y0_new[18] = np.zeros(10)
y0_new=y0_new.reshape(210)
p = sol_byi_20
y0_new=vaccinate_sus_y0(p,y0_new)
t = np.linspace(0,4*4*7,300)
sol=scipy.integrate.solve_ivp(lambda t,y:coronavirusEqs_with_vaccination_only(t,y, params),[0,4*4*7], y0_new, t_eval=t)
sol_plot=np.reshape(sol.y,(21,10,300))
deaths = sol_plot[18,:,-1]-deaths_from_curr_inf 
print(np.round(sum(deaths)))
print(np.round(deaths))
np.savetxt('min_id_both_ylls_20.txt', deaths)
sum(abs(plotting_fun2(deaths,total_pops)-1))
# Out:
# 170.0
# [  0.   2.   9.  22. 121.   0.   1.   2.   3.  10.]
# 2.7846528047717762
